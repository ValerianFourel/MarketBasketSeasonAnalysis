# %% [markdown]
# # Intro to Market Basket Analysis
#
# ### Valerian FOUREL
#
#
# We will here start the study of our Market Basket Analysis, with the handling of our data. The project to determine how does seasonality affect the Groceries habits of the customers of a particular store.

# %%
import numpy as np # we must import our packages for data pre-processing
import pandas as pd # we bring pandas which will be used extensively
from mlxtend.preprocessing import TransactionEncoder # we use the packages for the apriori algorithm
from mlxtend.frequent_patterns import apriori, association_rules # we bring in the association rule
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/rcmod.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %% [markdown]
# Questions to answer:
# - What does TransactionEncoder do?
# - How does TransactionEconder work?
# - What is the apriori Algorithm?
# - What are association Rules?

# %%
data_basket = pd.read_csv("basket.csv") # bring the data
data = pd.read_csv("GroceriesData.csv") # we add our data into a frame work
data = pd.DataFrame(data) # bring the data in a dataFrame

# %% [markdown]
# We must first create the Time Frame, we will study, we will first get it by season. We will infer whether, there are difference in results given the 4 different periods that we consider.
# We can then compare the application of the apriori algorithm on all seasons.

# %% [markdown]
# # Part 1: Exploring the Data
#
# The first part of the project is to explore the data, in order to obtain, 4 preprocess sets divided by seasonality on which it will be possible to use the Transaction Encoder.

# %%
seasons = 4 #Global variable

# %%
def seasonEncoding():
    seasons = [month%12 // 3 + 1 for month in range(1, 13)] # we get the number seasonality
    # by number first
    seasonResult = []
    for season in seasons:
        if season ==1:
            seasonResult.append("Winter") # we then append the season to a list matching the
            # index
        elif season ==2:
            seasonResult.append("Spring")
        elif season ==3:
            seasonResult.append("Summer")
        else:
            seasonResult.append("Fall")
    month_to_season = dict(zip(range(1,13), seasonResult)) # we get the dictionary from the
    # month number to the season
    return month_to_season

# %%
month_to_season = seasonEncoding()
month_to_season # we see the dictionary encoding the Season
# Out:
# {1: 'Winter',
#  2: 'Winter',
#  3: 'Spring',
#  4: 'Spring',
#  5: 'Spring',
#  6: 'Summer',
#  7: 'Summer',
#  8: 'Summer',
#  9: 'Fall',
#  10: 'Fall',
#  11: 'Fall',
#  12: 'Winter'}

# %%
data.head() # this is the "raw" data
# Out:
#    Member_number        Date   itemDescription  year  month  day  day_of_week
# 0           1808  2015-07-21    tropical fruit  2015      7   21            1
# 1           2552  2015-05-01        whole milk  2015      5    1            4
# 2           2300  2015-09-19         pip fruit  2015      9   19            5
# 3           1187  2015-12-12  other vegetables  2015     12   12            5
# 4           3037  2015-01-02        whole milk  2015      1    2            4

# %%
print(data['month'][0]) # the 7th month is July
month_to_season.get(data['month'][0]) #July is a summer month
# Out:
# 7
# 'Summer'

# %%
data['season'] = data['month'].apply(lambda month: month_to_season.get(month))
# WE add here the season to our Data frame, so we can then separate the transaction

# %%
data.head() # the season is present
# Out:
#    Member_number        Date   itemDescription  year  month  day  day_of_week  \
# 0           1808  2015-07-21    tropical fruit  2015      7   21            1
# 1           2552  2015-05-01        whole milk  2015      5    1            4
# 2           2300  2015-09-19         pip fruit  2015      9   19            5
# 3           1187  2015-12-12  other vegetables  2015     12   12            5
# 4           3037  2015-01-02        whole milk  2015      1    2            4
#
#    season
# 0  Summer
# 1  Spring
# 2    Fall
# 3  Winter
# 4  Winter

# %%
g = data.groupby(by='season') # we group by season

# %%
data = data.drop(columns=['year','month','day'],axis=1)

# %%
data_basket.head() # this is what we want for 4 different dataframe one for each season
# Out:
#              0                   1                    2       3    4    5  \
# 0   whole milk              pastry          salty snack     NaN  NaN  NaN
# 1      sausage          whole milk  semi-finished bread  yogurt  NaN  NaN
# 2         soda  pickled vegetables                  NaN     NaN  NaN  NaN
# 3  canned beer     misc. beverages                  NaN     NaN  NaN  NaN
# 4      sausage    hygiene articles                  NaN     NaN  NaN  NaN
#
#      6    7    8    9   10
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN

# %%
data_basket.fillna('!',inplace=True) # we must preprocess the data like the basket to be able to use mlxtend
trans = data_basket.values.tolist() 
data_basket.head() # this is what our data must look like after being transformed
# Out:
#              0                   1                    2       3  4  5  6  7  \
# 0   whole milk              pastry          salty snack       !  !  !  !  !
# 1      sausage          whole milk  semi-finished bread  yogurt  !  !  !  !
# 2         soda  pickled vegetables                    !       !  !  !  !  !
# 3  canned beer     misc. beverages                    !       !  !  !  !  !
# 4      sausage    hygiene articles                    !       !  !  !  !  !
#
#    8  9 10
# 0  !  !  !
# 1  !  !  !
# 2  !  !  !
# 3  !  !  !
# 4  !  !  !

# %%
dataSummer = data[data['season'] == 'Summer'] # for each season we encode it
dataWinter = data[data['season'] == 'Winter'] # for each season wer divide the data
dataFall = data[data['season'] == 'Fall']
dataSpring = data[data['season'] == 'Spring']

# %%
dataSummer # we verify what it looks like before transforming it into a basket of transaction
# Out:
#        Member_number        Date           itemDescription  day_of_week  \
# 0               1808  2015-07-21            tropical fruit            1
# 6               4501  2015-08-05          other vegetables            2
# 12              1997  2015-07-21               frankfurter            1
# 14              4736  2015-07-21                    butter            1
# 19              1905  2015-07-07          other vegetables            1
# ...              ...         ...                       ...          ...
# 38747           2639  2014-08-06     fruit/vegetable juice            2
# 38757           4376  2014-07-12                rolls/buns            5
# 38758           2511  2014-06-18  long life bakery product            2
# 38759           3364  2014-06-05                       oil            3
# 38760           4471  2014-08-10             sliced cheese            6
#
#        season
# 0      Summer
# 6      Summer
# 12     Summer
# 14     Summer
# 19     Summer
# ...       ...
# 38747  Summer
# 38757  Summer
# 38758  Summer
# 38759  Summer
# 38760  Summer
#
# [10082 rows x 5 columns]

# %%
dataSummer.shape
# Out:
# (10082, 5)

# %% [markdown]
# https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby

# %%
grp = dataSummer.sort_values(by=['Member_number', 'Date']) # we sort the 
# dataframe of summer by member ID and Date in order to later join the itemDespcriotn

dataSummer.groupby(['Member_number', 'Date'],group_keys=True).apply(lambda x: x)
# Out:
#        Member_number        Date           itemDescription  day_of_week  \
# 0               1808  2015-07-21            tropical fruit            1
# 6               4501  2015-08-05          other vegetables            2
# 12              1997  2015-07-21               frankfurter            1
# 14              4736  2015-07-21                    butter            1
# 19              1905  2015-07-07          other vegetables            1
# ...              ...         ...                       ...          ...
# 38747           2639  2014-08-06     fruit/vegetable juice            2
# 38757           4376  2014-07-12                rolls/buns            5
# 38758           2511  2014-06-18  long life bakery product            2
# 38759           3364  2014-06-05                       oil            3
# 38760           4471  2014-08-10             sliced cheese            6
#
#        season
# 0      Summer
# 6      Summer
# 12     Summer
# 14     Summer
# 19     Summer
# ...       ...
# 38747  Summer
# 38757  Summer
# 38758  Summer
# 38759  Summer
# 38760  Summer
#
# [10082 rows x 5 columns]

# %%
dataSummerTemp = dataSummer.copy() # we copy the Summer months for exploring the Data
dataSummerTemp
# Out:
#        Member_number        Date           itemDescription  day_of_week  \
# 0               1808  2015-07-21            tropical fruit            1
# 6               4501  2015-08-05          other vegetables            2
# 12              1997  2015-07-21               frankfurter            1
# 14              4736  2015-07-21                    butter            1
# 19              1905  2015-07-07          other vegetables            1
# ...              ...         ...                       ...          ...
# 38747           2639  2014-08-06     fruit/vegetable juice            2
# 38757           4376  2014-07-12                rolls/buns            5
# 38758           2511  2014-06-18  long life bakery product            2
# 38759           3364  2014-06-05                       oil            3
# 38760           4471  2014-08-10             sliced cheese            6
#
#        season
# 0      Summer
# 6      Summer
# 12     Summer
# 14     Summer
# 19     Summer
# ...       ...
# 38747  Summer
# 38757  Summer
# 38758  Summer
# 38759  Summer
# 38760  Summer
#
# [10082 rows x 5 columns]

# %%
dataSummerTemp = dataSummerTemp.sort_values(by=['Member_number', 'Date']) 
# we sort by Member_number first and by date second
maxValue = dataSummerTemp[['Member_number','Date','itemDescription']].groupby(['Member_number', 'Date']).count().max() 
# the max Value returns the transaction with the largest number of items for the Summer season 
dataSummerTemp['itemDescription'] = dataSummerTemp.groupby(['Member_number', 'Date'])['itemDescription'].transform(lambda x: ','.join(x))
# we must do the costly operation of joining, all of the transaction together

dataSummerTemp = dataSummerTemp[['Member_number','Date','itemDescription']].drop_duplicates()
# wethen drop all of the duplicates creating, to keep only one row per transaction

dataSummerTemp # the temporary data yields, a table with a Member ID, a date, and what was bought 
# by the customer on that day
# Out:
#        Member_number        Date  \
# 13331           1000  2014-06-24
# 2047            1000  2015-07-24
# 9391            1001  2014-07-02
# 4917            1002  2015-08-30
# 11398           1004  2014-08-19
# ...              ...         ...
# 11056           4991  2014-08-28
# 3970            4992  2015-06-20
# 12126           4993  2014-08-15
# 9826            4993  2014-08-19
# 2581            4994  2015-08-02
#
#                                          itemDescription
# 13331                      whole milk,pastry,salty snack
# 2047                         canned beer,misc. beverages
# 9391                       sausage,whole milk,rolls/buns
# 4917                     butter milk,specialty chocolate
# 11398                  root vegetables,whole milk,pastry
# ...                                                  ...
# 11056                        whole milk,other vegetables
# 3970   whole milk,other vegetables,pip fruit,sparklin...
# 12126                            onions,abrasive cleaner
# 9826                            tropical fruit,detergent
# 2581                       sausage,fruit/vegetable juice
#
# [3860 rows x 3 columns]

# %% [markdown]
# # Part 2: Creating our Basket for Analysis
#
# We have finished the first step of preprocessing our data, up to creating a  pandas framework, where for each transaction with a row with a full transaction record of the items.

# %%
def getSeasonBasket(dataSeason): # we can move forward by applying the trnasformation frtom above to each 
    # subset of the Groceries data divided by Seasons 
    
    assert isinstance(dataSeason, pd.DataFrame)
    dataSeasonTemp = dataSeason.copy()
    dataSeasonTemp = dataSeasonTemp.sort_values(by=['Member_number', 'Date'])
    maxValue = dataSeasonTemp[['Member_number','Date','itemDescription']].groupby(['Member_number', 'Date']).count().max()
    dataSeasonTemp['itemDescription'] = dataSeasonTemp.groupby(['Member_number', 'Date'])['itemDescription'].transform(lambda x: ','.join(x))

    dataSeasonTemp = dataSeasonTemp[['Member_number','Date','itemDescription']].drop_duplicates()
    maxVal = maxValue['itemDescription'] # we get the size of the biggest transaction
    
    itemList = []
    for i in range(maxVal):
        stringItem = 'Item{item}'.format(item = i)
        itemList.append(stringItem)
    
    dfSeason = pd.DataFrame(columns=itemList) # we create dataFrame for the summer 
    dfSeason[itemList] = dataSeasonTemp['itemDescription'].apply(lambda x: pd.Series(str(x).split(",")))
    dfSeason.fillna('!',inplace=True)

    return dfSeason

# %%
maxVal = maxValue['itemDescription'] # we get the biggest transaction

def itemListCount(maxVal): 
    itemList = []
    for i in range(maxVal):
        stringItem = 'Item{item}'.format(item = i)
        itemList.append(stringItem) # we count the number of items to make a fitted table
    return itemList


itemList = itemListCount(maxVal) # We make a list of the item number

dfSummer = pd.DataFrame(columns=itemList) # we create dataFrame for the summer 
dfSummer[itemList] = dataSummerTemp['itemDescription'].apply(lambda x: pd.Series(str(x).split(",")))
dfSummer.head()
# Out:
#                  Item0                Item1        Item2 Item3 Item4 Item5  \
# 13331       whole milk               pastry  salty snack   NaN   NaN   NaN
# 2047       canned beer      misc. beverages          NaN   NaN   NaN   NaN
# 9391           sausage           whole milk   rolls/buns   NaN   NaN   NaN
# 4917       butter milk  specialty chocolate          NaN   NaN   NaN   NaN
# 11398  root vegetables           whole milk       pastry   NaN   NaN   NaN
#
#       Item6 Item7 Item8
# 13331   NaN   NaN   NaN
# 2047    NaN   NaN   NaN
# 9391    NaN   NaN   NaN
# 4917    NaN   NaN   NaN
# 11398   NaN   NaN   NaN

# %%
dataSummer
# Out:
#        Member_number        Date           itemDescription  day_of_week  \
# 0               1808  2015-07-21            tropical fruit            1
# 6               4501  2015-08-05          other vegetables            2
# 12              1997  2015-07-21               frankfurter            1
# 14              4736  2015-07-21                    butter            1
# 19              1905  2015-07-07          other vegetables            1
# ...              ...         ...                       ...          ...
# 38747           2639  2014-08-06     fruit/vegetable juice            2
# 38757           4376  2014-07-12                rolls/buns            5
# 38758           2511  2014-06-18  long life bakery product            2
# 38759           3364  2014-06-05                       oil            3
# 38760           4471  2014-08-10             sliced cheese            6
#
#        season
# 0      Summer
# 6      Summer
# 12     Summer
# 14     Summer
# 19     Summer
# ...       ...
# 38747  Summer
# 38757  Summer
# 38758  Summer
# 38759  Summer
# 38760  Summer
#
# [10082 rows x 5 columns]

# %%
basketSpring = getSeasonBasket(dataSpring) # we get the Item for each data Set

# %%
basketSummer = getSeasonBasket(dataSummer)

# %%
basketFall = getSeasonBasket(dataFall)

# %%
basketWinter = getSeasonBasket(dataWinter)
basketWinter.head()
# Out:
#               Item0        Item1               Item2 Item3 Item4 Item5 Item6  \
# 11046    whole milk         soda                   !     !     !     !     !
# 364     frankfurter         soda  whipped/sour cream     !     !     !     !
# 5695    frankfurter         curd                   !     !     !     !     !
# 33021  frozen meals  dental care                   !     !     !     !     !
# 33098    rolls/buns   rolls/buns                   !     !     !     !     !
#
#       Item7 Item8 Item9 Item10
# 11046     !     !     !      !
# 364       !     !     !      !
# 5695      !     !     !      !
# 33021     !     !     !      !
# 33098     !     !     !      !

# %% [markdown]
# From here you can transform the data, in order to see the tentative results, that can be expected by using the mlxtend library.

# %% [markdown]
# ## What we need to do next
#
#
# We must take our 4 subset of the basket, and we must cross validate that the basket are the same, by looping for all.

# %% [markdown]
# # Part 3: The apriori algorithm
#
# We can move on next apply the Apriori Algorithm from mlxtend package for each of the seasons.

# %%
transSummer = basketSummer.values.tolist() # we must transform our pandas dataframe to a list of list 
# containg the items of each transaction

# %%
for i in range(len(transSummer)):
    transSummer[i] = [x for x in transSummer[i] if not x=='!']
transSummer
# Out:
# [['whole milk', 'pastry', 'salty snack'],
#  ['canned beer', 'misc. beverages'],
#  ['sausage', 'whole milk', 'rolls/buns'],
#  ['butter milk', 'specialty chocolate'],
#  ['root vegetables', 'whole milk', 'pastry'],
#  ['whole milk',
#   'frankfurter',
#   'chicken',
#   'frankfurter',
#   'flour',
#   'chocolate',
#   'bottled beer',
#   'rolls/buns'],
#  ['tropical fruit',
#   'soda',
#   'yogurt',
#   'root vegetables',
#   'yogurt',
#   'domestic eggs',
#   'white wine',
#   'photo/film'],
#  ['bottled water', 'specialty bar'],
#  ['frankfurter', 'bottled water'],
#  ['pip fruit', 'candles', 'rolls/buns'],
#  ['frozen vegetables', 'brown bread'],
#  ['other vegetables', 'mustard'],
#  ['whole milk', 'rolls/buns'],
#  ['fruit/vegetable juice', 'rolls/buns', 'chocolate'],
#  ['chicken', 'red/blush wine'],
#  ['yogurt', 'beef'],
#  ['frozen meals', 'butter', 'newspapers', 'yogurt'],
#  ['rolls/buns', 'baking powder'],
#  ['sausage', 'fruit/vegetable juice'],
#  ['domestic eggs', 'soda'],
#  ['whipped/sour cream',
#   'root vegetables',
#   'rolls/buns',
#   'packaged fruit/vegetables'],
#  ['white bread', 'bottled beer', 'yogurt', 'berries'],
#  ['coffee', 'shopping bags'],
#  ['canned beer', 'UHT-milk'],
#  ['root vegetables', 'long life bakery product'],
#  ['sausage', 'dessert', 'rolls/buns', 'pickled vegetables'],
#  ['citrus fruit', 'yogurt'],
#  ['beverages', 'cream cheese '],
#  ['berries',
#   'soda',
#   'butter',
#   'other vegetables',
#   'white bread',
#   'cream cheese '],
#  ['ice cream', 'whipped/sour cream'],
#  ['yogurt', 'root vegetables'],
#  ['chicken', 'waffles'],
#  ['whole milk', 'frozen vegetables'],
#  ['pip fruit', 'white wine', 'white bread', 'salt'],
#  ['whole milk', 'newspapers'],
#  ['citrus fruit', 'shopping bags', 'chewing gum', 'cake bar'],
#  ['yogurt', 'rolls/buns'],
#  ['chicken', 'frozen vegetables', 'candy'],
#  ['tropical fruit', 'brown bread', 'whole milk'],
#  ['prosecco', 'dessert'],
#  ['napkins', 'whole milk', 'chocolate marshmallow'],
#  ['whole milk', 'pastry'],
#  ['pork', 'bottled water'],
#  ['rolls/buns', 'condensed milk', 'whole milk', 'soda'],
#  ['specialty bar', 'margarine'],
#  ['house keeping products', 'yogurt'],
#  ['butter milk', 'yogurt', 'yogurt', 'margarine'],
#  ['soda', 'domestic eggs', 'sliced cheese', 'soda'],
#  ['tropical fruit', 'UHT-milk'],
#  ['yogurt', 'root vegetables'],
#  ['sausage', 'bottled water'],
#  ['sausage', 'salty snack', 'cling film/bags'],
#  ['whipped/sour cream', 'hard cheese'],
#  ['ham', 'whipped/sour cream', 'ketchup'],
#  ['white bread', 'frozen fruits'],
#  ['whole milk', 'citrus fruit'],
#  ['long life bakery product', 'root vegetables', 'other vegetables'],
#  ['rolls/buns', 'tropical fruit', 'coffee', 'chocolate'],
#  ['hamburger meat', 'pork'],
#  ['soda', 'yogurt'],
#  ['bottled beer', 'tropical fruit', 'sliced cheese', 'dishes'],
#  ['ham', 'other vegetables'],
#  ['pip fruit', 'curd', 'pip fruit', 'prosecco'],
#  ['oil', 'shopping bags'],
#  ['misc. beverages', 'instant coffee'],
#  ['UHT-milk', 'canned fish'],
#  ['frankfurter', 'frozen meals', 'dishes'],
#  ['other vegetables', 'butter'],
#  ['pastry', 'pasta'],
#  ['canned beer', 'rolls/buns', 'artif. sweetener', 'soda'],
#  ['chicken', 'soda'],
#  ['red/blush wine', 'bottled water', 'sweet spreads'],
#  ['other vegetables', 'frankfurter', 'newspapers', 'whole milk', 'pastry'],
#  ['specialty chocolate', 'soda', 'bathroom cleaner'],
#  ['pork', 'sliced cheese'],
#  ['root vegetables', 'citrus fruit'],
#  ['rolls/buns', 'soda'],
#  ['specialty chocolate', 'white bread'],
#  ['other vegetables', 'whole milk'],
#  ['herbs', 'pot plants', 'cake bar'],
#  ['sausage',
#   'whisky',
#   'specialty chocolate',
#   'dishes',
#   'yogurt',
#   'napkins',
#   'detergent',
#   'pastry'],
#  ['rolls/buns',
#   'grapes',
#   'bottled beer',
#   'sausage',
#   'salty snack',
#   'Instant food products',
#   'domestic eggs',
#   'bottled water'],
#  ['pasta', 'whole milk', 'waffles'],
#  ['newspapers', 'salty snack'],
#  ['chocolate marshmallow', 'other vegetables'],
#  ['sausage', 'tropical fruit', 'misc. beverages', 'root vegetables'],
#  ['sausage', 'whole milk'],
#  ['pickled vegetables', 'flour'],
#  ['pip fruit', 'fruit/vegetable juice'],
#  ['tropical fruit', 'candy'],
#  ['canned beer', 'napkins', 'rolls/buns'],
#  ['pip fruit', 'brown bread'],
#  ['root vegetables', 'instant coffee'],
#  ['spread cheese', 'pork'],
#  ['whole milk', 'processed cheese'],
#  ['other vegetables', 'white bread', 'detergent'],
#  ['waffles', 'hygiene articles', 'tea'],
#  ['other vegetables', 'white bread'],
#  ['onions', 'newspapers'],
#  ['rolls/buns', 'semi-finished bread'],
#  ['whole milk', 'pastry'],
#  ['citrus fruit', 'misc. beverages'],
#  ['frozen potato products', 'specialty cheese'],
#  ['salty snack', 'pastry', 'oil'],
#  ['brown bread', 'whole milk', 'shopping bags'],
#  ['chocolate', 'whole milk'],
#  ['citrus fruit', 'frozen vegetables', 'margarine'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['whole milk', 'yogurt', 'newspapers'],
#  ['turkey', 'root vegetables'],
#  ['other vegetables', 'napkins'],
#  ['brown bread', 'butter milk', 'canned vegetables', 'soda'],
#  ['chicken', 'bottled water'],
#  ['newspapers', 'white bread', 'rolls/buns', 'beverages'],
#  ['pip fruit', 'processed cheese', 'canned beer'],
#  ['ham', 'yogurt'],
#  ['tropical fruit', 'sugar'],
#  ['citrus fruit', 'brown bread'],
#  ['meat', 'other vegetables'],
#  ['root vegetables', 'frozen vegetables'],
#  ['yogurt', 'soda'],
#  ['sausage', 'pastry'],
#  ['soda', 'roll products '],
#  ['yogurt', 'softener'],
#  ['root vegetables', 'butter milk'],
#  ['herbs', 'citrus fruit'],
#  ['citrus fruit', 'napkins'],
#  ['pip fruit', 'other vegetables', 'cling film/bags'],
#  ['tropical fruit', 'yogurt'],
#  ['cat food', 'rolls/buns'],
#  ['chicken', 'brown bread'],
#  ['UHT-milk', 'soda'],
#  ['pork', 'domestic eggs'],
#  ['root vegetables', 'coffee'],
#  ['canned beer', 'fish'],
#  ['tropical fruit', 'root vegetables'],
#  ['soda', 'bottled beer', 'chicken', 'yogurt'],
#  ['long life bakery product', 'rolls/buns', 'UHT-milk', 'bottled water'],
#  ['pip fruit', 'berries'],
#  ['pork', 'domestic eggs'],
#  ['chicken', 'cake bar'],
#  ['whole milk', 'grapes'],
#  ['root vegetables', 'other vegetables', 'frozen vegetables'],
#  ['whole milk', 'cream cheese '],
#  ['frozen vegetables', 'domestic eggs'],
#  ['citrus fruit', 'soda'],
#  ['whole milk', 'root vegetables'],
#  ['domestic eggs', 'beef', 'coffee', 'bottled beer'],
#  ['red/blush wine', 'salty snack'],
#  ['canned beer', 'citrus fruit'],
#  ['frankfurter', 'frozen vegetables'],
#  ['specialty bar', 'newspapers'],
#  ['bottled beer', 'fruit/vegetable juice', 'rolls/buns'],
#  ['citrus fruit', 'syrup'],
#  ['citrus fruit', 'brown bread', 'specialty chocolate'],
#  ['bottled water', 'yogurt', 'beef', 'berries', 'chocolate', 'butter'],
#  ['pastry', 'other vegetables'],
#  ['tropical fruit', 'shopping bags'],
#  ['cereals', 'soda'],
#  ['citrus fruit', 'white bread'],
#  ['bottled beer', 'oil', 'whole milk', 'dishes'],
#  ['butter', 'mustard'],
#  ['root vegetables',
#   'ham',
#   'butter',
#   'brown bread',
#   'pastry',
#   'spread cheese'],
#  ['beef', 'whole milk', 'newspapers'],
#  ['root vegetables', 'sweet spreads'],
#  ['beef', 'whole milk', 'frozen meals'],
#  ['pip fruit', 'specialty bar', 'chocolate'],
#  ['soda', 'soda'],
#  ['bottled water', 'soda'],
#  ['hamburger meat', 'citrus fruit', 'specialty chocolate', 'other vegetables'],
#  ['butter', 'shopping bags'],
#  ['domestic eggs', 'newspapers'],
#  ['frozen fish', 'specialty chocolate'],
#  ['citrus fruit', 'root vegetables'],
#  ['yogurt', 'roll products '],
#  ['soda', 'curd cheese', 'root vegetables', 'semi-finished bread'],
#  ['rolls/buns', 'pastry'],
#  ['sliced cheese', 'pip fruit'],
#  ['rolls/buns', 'frozen meals'],
#  ['shopping bags', 'misc. beverages'],
#  ['ham', 'brown bread'],
#  ['tropical fruit', 'cat food'],
#  ['root vegetables', 'other vegetables'],
#  ['domestic eggs', 'fruit/vegetable juice'],
#  ['syrup', 'waffles'],
#  ['grapes', 'root vegetables', 'shopping bags'],
#  ['citrus fruit', 'long life bakery product'],
#  ['canned beer', 'brown bread'],
#  ['whole milk',
#   'soda',
#   'root vegetables',
#   'pastry',
#   'specialty fat',
#   'bottled water',
#   'napkins',
#   'tropical fruit'],
#  ['whole milk', 'sugar'],
#  ['pork', 'frozen meals'],
#  ['citrus fruit', 'citrus fruit'],
#  ['other vegetables', 'fruit/vegetable juice'],
#  ['tropical fruit', 'rolls/buns', 'frozen fish'],
#  ['pastry', 'waffles'],
#  ['canned beer', 'coffee'],
#  ['UHT-milk', 'cooking chocolate'],
#  ['yogurt', 'whipped/sour cream'],
#  ['mustard', 'brown bread'],
#  ['whole milk', 'other vegetables'],
#  ['grapes', 'detergent'],
#  ['pasta', 'canned beer'],
#  ['UHT-milk', 'curd'],
#  ['other vegetables', 'rolls/buns'],
#  ['chicken', 'whole milk'],
#  ['butter milk', 'other vegetables'],
#  ['canned beer', 'bottled beer'],
#  ['other vegetables', 'curd', 'abrasive cleaner'],
#  ['newspapers', 'pip fruit', 'dishes'],
#  ['pork', 'other vegetables', 'cream cheese '],
#  ['rolls/buns', 'hard cheese'],
#  ['finished products', 'yogurt', 'bottled beer', 'bottled water'],
#  ['brown bread', 'tropical fruit'],
#  ['onions', 'hard cheese'],
#  ['specialty chocolate', 'pasta', 'soda', 'long life bakery product'],
#  ['soda', 'cling film/bags'],
#  ['UHT-milk', 'soft cheese'],
#  ['soda', 'soda', 'canned fruit', 'processed cheese', 'soda', 'shopping bags'],
#  ['tropical fruit', 'rolls/buns'],
#  ['tropical fruit', 'berries'],
#  ['butter', 'candy'],
#  ['dessert', 'packaged fruit/vegetables'],
#  ['citrus fruit', 'skin care'],
#  ['tropical fruit', 'pip fruit'],
#  ['beef', 'curd'],
#  ['other vegetables', 'chewing gum'],
#  ['grapes', 'other vegetables'],
#  ['sausage', 'processed cheese', 'baking powder', 'specialty cheese'],
#  ['tea', 'coffee'],
#  ['berries', 'domestic eggs'],
#  ['UHT-milk', 'herbs', 'butter', 'oil'],
#  ['fruit/vegetable juice', 'berries'],
#  ['whole milk', 'domestic eggs', 'canned vegetables', 'flower (seeds)'],
#  ['whole milk', 'onions', 'pickled vegetables'],
#  ['tropical fruit', 'yogurt', 'semi-finished bread', 'soda'],
#  ['sausage', 'other vegetables', 'tropical fruit', 'mayonnaise'],
#  ['cream cheese ',
#   'pip fruit',
#   'citrus fruit',
#   'chicken',
#   'other vegetables',
#   'curd',
#   'specialty chocolate',
#   'pastry'],
#  ['other vegetables', 'sliced cheese'],
#  ['whole milk', 'misc. beverages'],
#  ['red/blush wine', 'frozen meals', 'canned fruit'],
#  ['specialty bar', 'cleaner'],
#  ['rolls/buns', 'dental care'],
#  ['ice cream', 'butter'],
#  ['root vegetables', 'butter', 'dessert'],
#  ['other vegetables', 'whole milk'],
#  ['dessert', 'house keeping products'],
#  ['whole milk', 'cream cheese ', 'semi-finished bread'],
#  ['photo/film',
#   'whole milk',
#   'yogurt',
#   'whole milk',
#   'white bread',
#   'pot plants',
#   'dessert'],
#  ['citrus fruit', 'hamburger meat', 'photo/film'],
#  ['meat', 'root vegetables'],
#  ['chicken', 'soda'],
#  ['tropical fruit', 'yogurt', 'sausage', 'rolls/buns'],
#  ['root vegetables', 'ham'],
#  ['rolls/buns', 'hamburger meat'],
#  ['white bread', 'shopping bags'],
#  ['soda', 'bottled water'],
#  ['napkins', 'whipped/sour cream'],
#  ['margarine', 'rolls/buns'],
#  ['citrus fruit', 'ice cream', 'butter', 'shopping bags'],
#  ['butter', 'rolls/buns'],
#  ['yogurt', 'hygiene articles'],
#  ['bottled beer', 'hygiene articles'],
#  ['herbs', 'dessert', 'yogurt'],
#  ['canned fruit', 'whipped/sour cream'],
#  ['chicken', 'other vegetables', 'frozen meals'],
#  ['soft cheese', 'flower (seeds)'],
#  ['whole milk',
#   'citrus fruit',
#   'pip fruit',
#   'butter',
#   'grapes',
#   'ice cream',
#   'margarine',
#   'whipped/sour cream'],
#  ['whole milk', 'packaged fruit/vegetables', 'abrasive cleaner', 'napkins'],
#  ['other vegetables', 'salty snack', 'brown bread', 'canned beer'],
#  ['whole milk', 'rolls/buns'],
#  ['canned beer', 'shopping bags'],
#  ['white wine', 'dishes'],
#  ['waffles', 'butter milk', 'domestic eggs'],
#  ['root vegetables', 'soda', 'other vegetables'],
#  ['frankfurter', 'chicken', 'processed cheese', 'dessert'],
#  ['pip fruit', 'root vegetables', 'root vegetables', 'beverages'],
#  ['tropical fruit', 'meat', 'hard cheese', 'jam'],
#  ['sausage', 'house keeping products'],
#  ['pastry', 'rolls/buns'],
#  ['chicken', 'soda', 'dishes'],
#  ['bottled beer', 'Instant food products'],
#  ['sausage', 'soda', 'frozen vegetables'],
#  ['citrus fruit', 'butter', 'rolls/buns'],
#  ['pasta', 'rolls/buns', 'margarine', 'canned fish', 'yogurt'],
#  ['hamburger meat', 'other vegetables'],
#  ['frankfurter', 'whole milk'],
#  ['spread cheese', 'root vegetables'],
#  ['whole milk', 'pork', 'rolls/buns', 'yogurt'],
#  ['yogurt', 'frozen vegetables'],
#  ['whole milk', 'sugar'],
#  ['meat', 'sausage', 'baking powder', 'pastry'],
#  ['white wine', 'waffles'],
#  ['pastry', 'pickled vegetables', 'margarine'],
#  ['rolls/buns', 'red/blush wine', 'canned beer'],
#  ['tropical fruit', 'rolls/buns'],
#  ['ham', 'chocolate'],
#  ['packaged fruit/vegetables', 'rolls/buns'],
#  ['citrus fruit', 'other vegetables'],
#  ['pip fruit', 'grapes', 'pastry'],
#  ['mayonnaise', 'processed cheese'],
#  ['root vegetables', 'coffee'],
#  ['soft cheese', 'bottled beer'],
#  ['whole milk', 'whole milk'],
#  ['packaged fruit/vegetables', 'chewing gum', 'ham', 'condensed milk', 'soda'],
#  ['cereals', 'frozen vegetables'],
#  ['other vegetables', 'whole milk'],
#  ['pastry', 'shopping bags'],
#  ['bottled beer', 'instant coffee'],
#  ['other vegetables', 'bottled beer'],
#  ['tropical fruit', 'pastry', 'cream cheese '],
#  ['tropical fruit', 'fruit/vegetable juice'],
#  ['condensed milk', 'domestic eggs'],
#  ['root vegetables', 'hard cheese'],
#  ['curd', 'butter'],
#  ['UHT-milk', 'bottled water'],
#  ['Instant food products', 'bottled beer', 'butter'],
#  ['chicken', 'onions'],
#  ['cling film/bags', 'napkins'],
#  ['bottled water', 'root vegetables', 'bottled beer', 'pastry'],
#  ['dessert', 'margarine'],
#  ['tropical fruit', 'frozen vegetables', 'rice'],
#  ['chicken', 'shopping bags', 'other vegetables', 'whole milk'],
#  ['soda', 'rolls/buns', 'shopping bags'],
#  ['frankfurter', 'grapes', 'salt', 'napkins', 'soda'],
#  ['pip fruit', 'domestic eggs'],
#  ['berries', 'semi-finished bread'],
#  ['whole milk', 'other vegetables'],
#  ['root vegetables', 'chewing gum', 'chocolate', 'bottled beer'],
#  ['other vegetables', 'root vegetables'],
#  ['napkins', 'butter milk', 'cat food', 'shopping bags'],
#  ['hard cheese', 'soda'],
#  ['root vegetables', 'canned beer'],
#  ['ham', 'brown bread'],
#  ['curd', 'processed cheese'],
#  ['whole milk', 'pastry'],
#  ['other vegetables', 'liquor'],
#  ['whole milk', 'beef', 'rolls/buns', 'mustard'],
#  ['curd', 'whole milk', 'bottled water'],
#  ['whole milk', 'chocolate'],
#  ['whole milk', 'pastry', 'butter', 'whole milk'],
#  ['dish cleaner', 'whole milk'],
#  ['citrus fruit', 'frozen dessert'],
#  ['root vegetables', 'ice cream'],
#  ['soda', 'whipped/sour cream'],
#  ['rolls/buns', 'whole milk'],
#  ['sausage', 'frozen fruits'],
#  ['other vegetables', 'sweet spreads'],
#  ['beef', 'soft cheese'],
#  ['other vegetables', 'canned fish', 'white bread', 'waffles'],
#  ['white bread',
#   'whole milk',
#   'white bread',
#   'whole milk',
#   'newspapers',
#   'rolls/buns',
#   'canned beer',
#   'whole milk'],
#  ['root vegetables', 'misc. beverages'],
#  ['frozen fish', 'whole milk', 'tropical fruit', 'butter', 'coffee'],
#  ['curd', 'grapes', 'soups', 'whole milk'],
#  ['sausage', 'soda', 'cream cheese '],
#  ['meat', 'whole milk', 'bottled water', 'mayonnaise'],
#  ['chicken', 'onions', 'white bread'],
#  ['other vegetables', 'herbs'],
#  ['popcorn', 'domestic eggs', 'canned beer', 'butter milk'],
#  ['pastry', 'pastry'],
#  ['other vegetables', 'soda', 'UHT-milk', 'salty snack'],
#  ['citrus fruit', 'rolls/buns'],
#  ['other vegetables', 'rolls/buns'],
#  ['waffles', 'instant coffee'],
#  ['whipped/sour cream', 'curd'],
#  ['pork', 'soda'],
#  ['rolls/buns', 'ice cream'],
#  ['rolls/buns', 'shopping bags', 'cream cheese '],
#  ['ham', 'yogurt'],
#  ['napkins', 'butter'],
#  ['chocolate', 'dessert', 'flour'],
#  ['yogurt', 'yogurt'],
#  ['pastry', 'red/blush wine'],
#  ['canned beer', 'tropical fruit', 'root vegetables', 'other vegetables'],
#  ['cream cheese ', 'other vegetables'],
#  ['pork', 'salty snack'],
#  ['tropical fruit',
#   'pork',
#   'coffee',
#   'canned beer',
#   'shopping bags',
#   'chocolate'],
#  ['specialty chocolate', 'sugar', 'domestic eggs'],
#  ['other vegetables', 'other vegetables'],
#  ['frozen vegetables', 'pasta'],
#  ['beef', 'citrus fruit', 'pastry'],
#  ['white wine', 'ham', 'whole milk', 'coffee', 'bottled water'],
#  ['root vegetables', 'whole milk', 'soda'],
#  ['sausage', 'tropical fruit'],
#  ['sausage', 'dishes', 'rum'],
#  ['kitchen towels', 'bottled beer'],
#  ['whipped/sour cream', 'shopping bags'],
#  ['specialty chocolate', 'soda', 'pet care'],
#  ['other vegetables', 'mustard', 'soups'],
#  ['UHT-milk', 'soda', 'salty snack'],
#  ['rolls/buns', 'newspapers', 'specialty fat', 'domestic eggs'],
#  ['make up remover', 'shopping bags'],
#  ['ham', 'canned beer'],
#  ['cream cheese ', 'fruit/vegetable juice'],
#  ['sliced cheese', 'onions'],
#  ['other vegetables', 'other vegetables'],
#  ['other vegetables', 'zwieback', 'oil'],
#  ['UHT-milk', 'other vegetables'],
#  ['pip fruit', 'pot plants'],
#  ['soda', 'curd'],
#  ['citrus fruit', 'bottled water'],
#  ['yogurt', 'misc. beverages', 'brown bread', 'napkins'],
#  ['root vegetables', 'hygiene articles', 'newspapers'],
#  ['canned beer', 'hygiene articles'],
#  ['curd', 'rolls/buns'],
#  ['pip fruit', 'soda'],
#  ['bottled beer', 'beverages', 'hard cheese', 'fruit/vegetable juice'],
#  ['other vegetables', 'curd'],
#  ['citrus fruit', 'root vegetables'],
#  ['spices', 'shopping bags', 'soda', 'newspapers'],
#  ['potato products', 'pip fruit'],
#  ['onions', 'butter'],
#  ['margarine', 'soda', 'UHT-milk'],
#  ['whole milk', 'pip fruit'],
#  ['citrus fruit', 'bottled water', 'specialty bar'],
#  ['yogurt', 'domestic eggs'],
#  ['specialty chocolate', 'baking powder', 'soda'],
#  ['beef', 'salty snack'],
#  ['salty snack', 'coffee'],
#  ['frankfurter', 'whole milk', 'whole milk'],
#  ['tropical fruit', 'fruit/vegetable juice'],
#  ['whole milk', 'chocolate'],
#  ['rolls/buns', 'rolls/buns'],
#  ['shopping bags', 'shopping bags'],
#  ['sausage', 'tropical fruit'],
#  ['citrus fruit', 'yogurt'],
#  ['pastry', 'onions'],
#  ['chicken', 'misc. beverages'],
#  ['tropical fruit', 'bottled water', 'dessert'],
#  ['whole milk', 'shopping bags', 'newspapers'],
#  ['butter', 'syrup', 'pickled vegetables', 'whole milk'],
#  ['brown bread', 'bottled water', 'pastry', 'curd'],
#  ['whole milk', 'other vegetables'],
#  ['specialty bar', 'misc. beverages'],
#  ['hamburger meat', 'bottled beer', 'coffee', 'instant coffee', 'yogurt'],
#  ['tropical fruit', 'bottled water', 'kitchen towels', 'processed cheese'],
#  ['whole milk', 'whole milk', 'domestic eggs'],
#  ['pork', 'canned beer', 'specialty bar'],
#  ['citrus fruit', 'whole milk', 'curd', 'chocolate marshmallow'],
#  ['waffles', 'yogurt'],
#  ['hamburger meat',
#   'tropical fruit',
#   'bottled water',
#   'whipped/sour cream',
#   'flour'],
#  ['sausage', 'pastry', 'soda'],
#  ['whole milk', 'newspapers'],
#  ['napkins', 'packaged fruit/vegetables', 'shopping bags'],
#  ['meat', 'sausage', 'other vegetables', 'shopping bags'],
#  ['hamburger meat', 'candy'],
#  ['ice cream', 'white bread', 'whole milk', 'bottled water'],
#  ['ham', 'pickled vegetables', 'newspapers'],
#  ['root vegetables', 'salty snack'],
#  ['coffee', 'salty snack'],
#  ['yogurt', 'butter'],
#  ['tropical fruit', 'whole milk'],
#  ['root vegetables', 'whole milk'],
#  ['meat', 'whole milk', 'newspapers'],
#  ['white bread', 'root vegetables'],
#  ['frankfurter', 'Instant food products'],
#  ['yogurt', 'shopping bags'],
#  ['liquor', 'rolls/buns', 'cream cheese '],
#  ['whipped/sour cream', 'hard cheese'],
#  ['chicken', 'pastry'],
#  ['berries', 'packaged fruit/vegetables', 'tidbits'],
#  ['bottled beer',
#   'whole milk',
#   'soda',
#   'whole milk',
#   'soft cheese',
#   'soda',
#   'shopping bags',
#   'sugar'],
#  ['bottled beer', 'sausage', 'cream cheese ', 'frozen vegetables'],
#  ['root vegetables', 'canned beer', 'specialty cheese', 'rolls/buns'],
#  ['rolls/buns', 'liquor (appetizer)'],
#  ['beef', 'soda', 'white wine', 'soft cheese'],
#  ['sausage', 'bottled beer'],
#  ['pastry', 'dish cleaner'],
#  ['root vegetables', 'white bread'],
#  ['beef', 'grapes'],
#  ['vinegar', 'newspapers', 'brown bread'],
#  ['rolls/buns', 'tropical fruit', 'soda', 'dessert'],
#  ['frozen vegetables', 'dessert'],
#  ['hygiene articles', 'other vegetables'],
#  ['frankfurter', 'citrus fruit'],
#  ['organic sausage', 'processed cheese', 'oil'],
#  ['frozen fish', 'whole milk'],
#  ['meat', 'other vegetables'],
#  ['shopping bags', 'butter milk'],
#  ['long life bakery product', 'rolls/buns'],
#  ['rolls/buns', 'frozen vegetables'],
#  ['hygiene articles', 'chocolate', 'soups'],
#  ['rolls/buns', 'frankfurter', 'soda', 'canned fish'],
#  ['sausage', 'pasta'],
#  ['curd', 'butter'],
#  ['bottled water', 'napkins', 'fruit/vegetable juice', 'hard cheese'],
#  ['chicken', 'finished products', 'meat', 'fruit/vegetable juice'],
#  ['bottled beer', 'whole milk'],
#  ['shopping bags', 'beef', 'citrus fruit', 'cat food'],
#  ['bottled water', 'hair spray', 'processed cheese'],
#  ['chicken', 'frozen fish', 'sugar'],
#  ['other vegetables', 'whole milk'],
#  ['bottled water', 'curd'],
#  ['whipped/sour cream', 'citrus fruit'],
#  ['whole milk', 'pasta'],
#  ['bottled beer', 'candy'],
#  ['tropical fruit', 'yogurt'],
#  ['pastry', 'other vegetables'],
#  ['tropical fruit', 'domestic eggs', 'chocolate'],
#  ['whole milk', 'waffles', 'shopping bags'],
#  ['newspapers', 'yogurt'],
#  ['whipped/sour cream', 'brown bread'],
#  ['UHT-milk', 'cream cheese ', 'cream cheese ', 'waffles'],
#  ['sausage', 'bottled beer', 'sliced cheese'],
#  ['yogurt', 'rolls/buns'],
#  ['yogurt', 'shopping bags'],
#  ['frankfurter', 'soda'],
#  ['whole milk', 'citrus fruit', 'napkins'],
#  ['citrus fruit', 'other vegetables'],
#  ['pastry',
#   'rolls/buns',
#   'sliced cheese',
#   'tropical fruit',
#   'liquor',
#   'hygiene articles',
#   'dental care',
#   'napkins'],
#  ['pork', 'other vegetables'],
#  ['napkins', 'whole milk'],
#  ['root vegetables', 'tropical fruit'],
#  ['other vegetables', 'yogurt', 'soda'],
#  ['sausage', 'hamburger meat'],
#  ['frankfurter', 'margarine'],
#  ['whole milk', 'beef', 'beverages', 'yogurt'],
#  ['sausage', 'hamburger meat', 'newspapers'],
#  ['hamburger meat', 'popcorn'],
#  ['pork', 'whole milk'],
#  ['onions', 'whole milk', 'cling film/bags'],
#  ['liver loaf', 'bottled water', 'bottled water'],
#  ['dessert', 'curd'],
#  ['pip fruit', 'UHT-milk', 'soda'],
#  ['yogurt', 'other vegetables'],
#  ['other vegetables', 'sliced cheese'],
#  ['finished products', 'other vegetables'],
#  ['whole milk', 'domestic eggs', 'long life bakery product'],
#  ['snack products', 'soda'],
#  ['tropical fruit', 'yogurt'],
#  ['other vegetables', 'curd'],
#  ['onions', 'chocolate'],
#  ['finished products', 'frozen vegetables'],
#  ['specialty chocolate', 'whipped/sour cream'],
#  ['soda', 'onions', 'pastry'],
#  ['white bread', 'seasonal products'],
#  ['napkins', 'citrus fruit'],
#  ['packaged fruit/vegetables', 'bottled beer'],
#  ['specialty bar', 'canned beer'],
#  ['citrus fruit', 'whole milk'],
#  ['other vegetables', 'pip fruit', 'domestic eggs'],
#  ['meat', 'butter'],
#  ['grapes', 'onions'],
#  ['curd', 'shopping bags'],
#  ['sausage', 'margarine'],
#  ['frankfurter', 'sausage', 'pastry', 'newspapers', 'newspapers', 'honey'],
#  ['other vegetables', 'yogurt'],
#  ['root vegetables', 'processed cheese'],
#  ['hamburger meat', 'root vegetables'],
#  ['fruit/vegetable juice', 'pip fruit'],
#  ['coffee', 'whole milk'],
#  ['sausage', 'rolls/buns', 'rolls/buns'],
#  ['beef', 'newspapers'],
#  ['bottled beer', 'rolls/buns', 'whole milk'],
#  ['finished products', 'whole milk'],
#  ['whole milk', 'other vegetables', 'pot plants'],
#  ['bottled water', 'beverages'],
#  ['ice cream', 'soda'],
#  ['sausage', 'rolls/buns'],
#  ['citrus fruit', 'beef'],
#  ['whole milk', 'frankfurter', 'domestic eggs', 'flour'],
#  ['canned beer', 'whole milk'],
#  ['canned beer', 'white bread'],
#  ['sausage', 'margarine'],
#  ['white wine', 'rolls/buns'],
#  ['sausage', 'seasonal products'],
#  ['yogurt', 'citrus fruit'],
#  ['napkins', 'pastry', 'whole milk'],
#  ['whole milk',
#   'red/blush wine',
#   'shopping bags',
#   'cream cheese ',
#   'canned beer'],
#  ['pickled vegetables', 'butter'],
#  ['butter', 'soda', 'oil'],
#  ['bottled water', 'frozen vegetables'],
#  ['turkey', 'whipped/sour cream'],
#  ['soda', 'cream cheese '],
#  ['yogurt', 'cookware'],
#  ['herbs', 'white bread', 'curd cheese'],
#  ['whole milk', 'frozen meals'],
#  ['whole milk', 'pastry'],
#  ['whole milk', 'pip fruit'],
#  ['sauces', 'frozen meals'],
#  ['sugar', 'dish cleaner'],
#  ['bottled beer', 'sugar', 'popcorn'],
#  ['hamburger meat', 'candy', 'napkins'],
#  ['dessert', 'napkins', 'long life bakery product'],
#  ['frozen meals', 'cream cheese '],
#  ['chicken', 'yogurt'],
#  ['other vegetables', 'soda'],
#  ['bottled beer', 'yogurt', 'butter milk'],
#  ['sugar', 'butter milk', 'photo/film'],
#  ['whole milk', 'salty snack'],
#  ['canned fish', 'rolls/buns'],
#  ['other vegetables', 'beverages'],
#  ['zwieback', 'rice'],
#  ['other vegetables', 'packaged fruit/vegetables'],
#  ['fruit/vegetable juice', 'cream cheese '],
#  ['yogurt', 'whole milk'],
#  ['frozen dessert', 'tropical fruit'],
#  ['tropical fruit', 'herbs'],
#  ['chicken', 'napkins', 'soda'],
#  ['other vegetables', 'liquor (appetizer)'],
#  ['prosecco', 'chewing gum'],
#  ['long life bakery product', 'chocolate'],
#  ['ham', 'female sanitary products'],
#  ['root vegetables', 'newspapers'],
#  ['other vegetables', 'candy'],
#  ['UHT-milk', 'whipped/sour cream'],
#  ['salty snack', 'brown bread', 'napkins'],
#  ['white bread', 'frozen vegetables'],
#  ['shopping bags', 'hygiene articles'],
#  ['chewing gum', 'ham'],
#  ['butter milk', 'sliced cheese', 'rolls/buns'],
#  ['soda', 'frankfurter', 'butter', 'whole milk'],
#  ['pork', 'condensed milk'],
#  ['tropical fruit', 'white wine', 'bottled beer'],
#  ['bottled water', 'berries'],
#  ['cream cheese ', 'misc. beverages'],
#  ['cat food', 'canned vegetables'],
#  ['tropical fruit', 'other vegetables'],
#  ['beef', 'chicken'],
#  ['bottled beer', 'canned beer', 'fruit/vegetable juice'],
#  ['beef', 'curd'],
#  ['chicken', 'herbs', 'frozen meals'],
#  ['pip fruit', 'frozen vegetables', 'butter milk'],
#  ['whole milk', 'frozen dessert'],
#  ['whole milk', 'other vegetables'],
#  ['whole milk', 'butter'],
#  ['brown bread', 'frozen fish'],
#  ['tropical fruit', 'dessert', 'white bread', 'bottled water'],
#  ['hard cheese', 'bottled beer', 'whole milk', 'liquor (appetizer)'],
#  ['pork', 'coffee', 'margarine'],
#  ['beef', 'butter'],
#  ['frankfurter', 'bottled water'],
#  ['misc. beverages', 'sliced cheese', 'domestic eggs'],
#  ['beef', 'specialty chocolate'],
#  ['dessert', 'mustard', 'white bread'],
#  ['tropical fruit', 'frozen fruits'],
#  ['pip fruit', 'white wine', 'shopping bags'],
#  ['rolls/buns', 'onions', 'butter', 'whole milk', 'rolls/buns'],
#  ['pork', 'sugar'],
#  ['curd cheese', 'canned beer'],
#  ['turkey', 'bottled water'],
#  ['citrus fruit', 'female sanitary products'],
#  ['soda',
#   'sausage',
#   'root vegetables',
#   'pork',
#   'whole milk',
#   'vinegar',
#   'other vegetables',
#   'domestic eggs',
#   'shopping bags'],
#  ['chicken', 'pork', 'newspapers'],
#  ['whole milk', 'yogurt'],
#  ['citrus fruit', 'grapes'],
#  ['chicken', 'ice cream', 'bottled water'],
#  ['detergent', 'tropical fruit', 'soda', 'margarine'],
#  ['citrus fruit', 'onions'],
#  ['yogurt', 'seasonal products'],
#  ['bottled water', 'whole milk'],
#  ['rolls/buns', 'brown bread', 'whipped/sour cream'],
#  ['other vegetables', 'frozen vegetables', 'rolls/buns'],
#  ['whole milk', 'rolls/buns', 'salty snack'],
#  ['pip fruit', 'popcorn', 'rolls/buns', 'bottled water'],
#  ['pip fruit',
#   'pip fruit',
#   'whipped/sour cream',
#   'shopping bags',
#   'domestic eggs',
#   'soda',
#   'cake bar',
#   'frozen meals'],
#  ['whole milk', 'pip fruit'],
#  ['other vegetables', 'whole milk'],
#  ['specialty bar', 'other vegetables', 'misc. beverages'],
#  ['chicken', 'house keeping products'],
#  ['sugar', 'curd'],
#  ['dessert', 'fruit/vegetable juice', 'napkins'],
#  ['whole milk', 'soda', 'other vegetables'],
#  ['citrus fruit', 'chicken'],
#  ['rolls/buns', 'butter'],
#  ['whole milk', 'coffee'],
#  ['cream cheese ', 'yogurt'],
#  ['domestic eggs', 'root vegetables'],
#  ['pip fruit', 'other vegetables'],
#  ['other vegetables', 'citrus fruit', 'pork', 'shopping bags'],
#  ['other vegetables', 'yogurt', 'brown bread'],
#  ['canned vegetables', 'chicken', 'rolls/buns'],
#  ['white bread', 'cream cheese '],
#  ['frozen fish', 'whole milk'],
#  ['coffee', 'bottled water', 'chocolate'],
#  ['canned beer', 'brandy', 'waffles', 'cat food', 'dishes', 'light bulbs'],
#  ['white bread', 'coffee'],
#  ['specialty chocolate', 'rolls/buns'],
#  ['soda', 'soda'],
#  ['frankfurter', 'whole milk', 'hamburger meat', 'white bread'],
#  ['spread cheese', 'butter', 'hygiene articles'],
#  ['margarine', 'bottled water'],
#  ['brown bread', 'pip fruit'],
#  ['rolls/buns', 'pip fruit'],
#  ['pip fruit', 'bottled water'],
#  ['brown bread', 'pet care'],
#  ['bottled water', 'soda'],
#  ['tropical fruit', 'whole milk'],
#  ['tropical fruit', 'whole milk'],
#  ['chewing gum', 'pastry', 'pastry'],
#  ['citrus fruit', 'newspapers', 'shopping bags'],
#  ['tropical fruit', 'margarine'],
#  ['whole milk', 'canned beer'],
#  ['curd', 'chicken'],
#  ['citrus fruit', 'beef'],
#  ['rolls/buns', 'rum'],
#  ['soda', 'bottled water', 'ice cream'],
#  ['frankfurter', 'rolls/buns', 'newspapers', 'waffles'],
#  ['meat', 'whole milk', 'ready soups'],
#  ['sugar', 'napkins'],
#  ['other vegetables', 'processed cheese'],
#  ['whole milk', 'whole milk'],
#  ['pip fruit', 'canned fish', 'organic sausage', 'pastry'],
#  ['napkins', 'yogurt'],
#  ['other vegetables', 'beverages'],
#  ['rolls/buns', 'bottled water'],
#  ['sausage', 'tropical fruit', 'pork', 'rolls/buns'],
#  ['soda', 'napkins'],
#  ['butter', 'soda'],
#  ['rolls/buns', 'pickled vegetables', 'chocolate', 'whole milk'],
#  ['sausage', 'detergent'],
#  ['dessert', 'pastry'],
#  ['brown bread', 'soda'],
#  ['whipped/sour cream', 'rolls/buns'],
#  ['tropical fruit', 'white bread'],
#  ['specialty bar', 'soda'],
#  ['margarine', 'bottled beer'],
#  ['rolls/buns', 'packaged fruit/vegetables'],
#  ['canned beer', 'soda'],
#  ['pip fruit', 'bottled water'],
#  ['frankfurter', 'margarine', 'frozen vegetables'],
#  ['roll products ', 'rolls/buns'],
#  ['whipped/sour cream', 'yogurt', 'processed cheese', 'rolls/buns'],
#  ['kitchen utensil', 'bottled water', 'rolls/buns', 'pasta', 'bottled water'],
#  ['bottled beer', 'butter'],
#  ['pip fruit',
#   'roll products ',
#   'beverages',
#   'whole milk',
#   'canned fish',
#   'sugar'],
#  ['shopping bags', 'rolls/buns'],
#  ['root vegetables', 'dog food'],
#  ['onions', 'pastry', 'soda'],
#  ['other vegetables', 'cream cheese '],
#  ['hygiene articles', 'pastry'],
#  ['root vegetables', 'pickled vegetables'],
#  ['root vegetables', 'pickled vegetables'],
#  ['pastry', 'bottled water'],
#  ['canned beer', 'curd', 'coffee', 'flour'],
#  ['frankfurter',
#   'finished products',
#   'canned beer',
#   'hamburger meat',
#   'packaged fruit/vegetables',
#   'whipped/sour cream',
#   'curd',
#   'sweet spreads',
#   'white bread'],
#  ['bottled water', 'flour'],
#  ['cream cheese ', 'margarine', 'dish cleaner'],
#  ['tropical fruit', 'UHT-milk'],
#  ['whole milk', 'root vegetables'],
#  ['flower soil/fertilizer', 'butter milk'],
#  ['bottled beer', 'canned vegetables'],
#  ['butter', 'newspapers'],
#  ['domestic eggs', 'other vegetables'],
#  ['finished products',
#   'butter milk',
#   'fruit/vegetable juice',
#   'brown bread',
#   'pot plants'],
#  ['long life bakery product', 'rolls/buns'],
#  ['sugar', 'whole milk'],
#  ['dessert', 'sausage', 'whole milk', 'oil'],
#  ['specialty chocolate', 'butter milk'],
#  ['rolls/buns', 'other vegetables', 'newspapers'],
#  ['soda', 'yogurt'],
#  ['rolls/buns', 'candy', 'white bread'],
#  ['sausage', 'UHT-milk'],
#  ['sausage', 'fruit/vegetable juice', 'whole milk', 'curd'],
#  ['butter', 'canned beer', 'brown bread', 'canned beer'],
#  ['ham', 'berries'],
#  ['pork', 'liquor', 'long life bakery product'],
#  ['pork', 'bottled water'],
#  ['tropical fruit',
#   'newspapers',
#   'beef',
#   'tropical fruit',
#   'domestic eggs',
#   'detergent',
#   'frozen vegetables',
#   'grapes',
#   'processed cheese'],
#  ['beef', 'hard cheese'],
#  ['chocolate', 'coffee'],
#  ['sausage', 'other vegetables'],
#  ['sausage', 'detergent', 'bottled beer'],
#  ['hard cheese', 'processed cheese'],
#  ['white wine', 'sugar'],
#  ['bottled beer', 'hamburger meat'],
#  ['instant coffee', 'domestic eggs'],
#  ['whole milk', 'male cosmetics'],
#  ['canned beer', 'canned fish'],
#  ['canned beer', 'other vegetables'],
#  ['whole milk', 'white wine'],
#  ['vinegar', 'rolls/buns'],
#  ['canned beer', 'sugar'],
#  ['other vegetables', 'soda'],
#  ['white bread', 'brown bread'],
#  ['onions', 'instant coffee'],
#  ['whipped/sour cream', 'shopping bags'],
#  ['beverages',
#   'beverages',
#   'hamburger meat',
#   'frankfurter',
#   'soda',
#   'root vegetables',
#   'butter',
#   'cream cheese ',
#   'butter'],
#  ['finished products', 'popcorn'],
#  ['tropical fruit', 'rolls/buns', 'candy'],
#  ['pork', 'other vegetables'],
#  ['other vegetables', 'hygiene articles'],
#  ['long life bakery product', 'bottled beer'],
#  ['hamburger meat', 'other vegetables'],
#  ['other vegetables', 'bottled water'],
#  ['fruit/vegetable juice', 'whole milk'],
#  ['onions', 'butter'],
#  ['beef', 'sausage'],
#  ['red/blush wine', 'liquor (appetizer)', 'sauces', 'coffee'],
#  ['pickled vegetables', 'canned beer'],
#  ['canned beer', 'hamburger meat'],
#  ['other vegetables', 'bottled water', 'beverages'],
#  ['pip fruit', 'soda', 'grapes'],
#  ['pork', 'ham'],
#  ['sausage', 'canned beer'],
#  ['long life bakery product', 'UHT-milk', 'whole milk'],
#  ['chicken', 'bottled beer', 'soda', 'domestic eggs', 'other vegetables'],
#  ['sausage', 'spread cheese', 'specialty bar', 'soda'],
#  ['herbs', 'spread cheese', 'rolls/buns'],
#  ['pork', 'pork', 'male cosmetics'],
#  ['citrus fruit', 'bottled water'],
#  ['whole milk', 'sauces', 'hard cheese'],
#  ['whole milk', 'coffee', 'bottled beer'],
#  ['frozen chicken', 'dessert'],
#  ['pastry', 'detergent', 'rice'],
#  ['rolls/buns', 'jam', 'cake bar'],
#  ['oil', 'herbs'],
#  ['bottled beer', 'domestic eggs'],
#  ['other vegetables', 'ice cream'],
#  ['pip fruit', 'salty snack'],
#  ['pastry', 'waffles', 'napkins'],
#  ['tropical fruit', 'brown bread'],
#  ['other vegetables', 'chicken'],
#  ['UHT-milk',
#   'pip fruit',
#   'specialty chocolate',
#   'chewing gum',
#   'canned fruit'],
#  ['other vegetables', 'root vegetables', 'mayonnaise'],
#  ['rolls/buns', 'oil'],
#  ['hamburger meat', 'whole milk'],
#  ['frankfurter', 'fruit/vegetable juice'],
#  ['sauces', 'frozen vegetables'],
#  ['whole milk', 'butter', 'shopping bags'],
#  ['pork', 'soda'],
#  ['berries', 'whole milk', 'other vegetables'],
#  ['soda', 'fruit/vegetable juice'],
#  ['cake bar', 'shopping bags'],
#  ['hygiene articles', 'bottled water', 'candy'],
#  ['other vegetables', 'newspapers'],
#  ['other vegetables', 'skin care', 'domestic eggs'],
#  ['soda', 'semi-finished bread'],
#  ['pip fruit', 'yogurt'],
#  ['bottled beer', 'brown bread'],
#  ['butter', 'other vegetables'],
#  ['chocolate', 'whole milk', 'yogurt'],
#  ['chicken', 'pastry'],
#  ['pet care', 'pip fruit', 'candy'],
#  ['waffles', 'other vegetables'],
#  ['citrus fruit', 'rolls/buns'],
#  ['brown bread', 'shopping bags'],
#  ['whole milk', 'baking powder'],
#  ['other vegetables', 'berries'],
#  ['citrus fruit', 'pastry'],
#  ['frozen vegetables', 'yogurt'],
#  ['mustard', 'sugar', 'baking powder'],
#  ['coffee', 'butter milk'],
#  ['tropical fruit', 'frozen meals'],
#  ['whipped/sour cream', 'cake bar'],
#  ['bottled water', 'butter', 'waffles'],
#  ['soda', 'flour', 'brown bread'],
#  ['curd', 'UHT-milk'],
#  ['shopping bags', 'soda', 'soups'],
#  ['yogurt', 'rolls/buns'],
#  ['whole milk', 'other vegetables'],
#  ['whipped/sour cream', 'baking powder'],
#  ['soda', 'oil'],
#  ['other vegetables', 'grapes'],
#  ['pork', 'butter'],
#  ['pork', 'yogurt', 'napkins'],
#  ['ham', 'beef', 'sliced cheese', 'butter milk'],
#  ['ketchup', 'rolls/buns'],
#  ['herbs', 'canned beer'],
#  ['ham', 'chicken'],
#  ['butter', 'pastry'],
#  ['other vegetables', 'specialty bar'],
#  ['salt', 'margarine'],
#  ['root vegetables', 'waffles', 'cream cheese '],
#  ['other vegetables', 'canned beer'],
#  ['frankfurter', 'bottled water', 'onions'],
#  ['butter milk', 'hard cheese'],
#  ['brown bread', 'sugar', 'beef', 'citrus fruit', 'yogurt'],
#  ['candles', 'other vegetables'],
#  ['soda', 'fruit/vegetable juice'],
#  ['other vegetables', 'soda'],
#  ['whole milk', 'dish cleaner'],
#  ['chewing gum', 'yogurt'],
#  ['other vegetables',
#   'tropical fruit',
#   'seasonal products',
#   'butter',
#   'shopping bags'],
#  ['ham', 'whole milk', 'candy'],
#  ['sausage', 'newspapers', 'cream'],
#  ['pip fruit', 'soda'],
#  ['ice cream', 'butter'],
#  ['sausage', 'chicken', 'margarine', 'yogurt'],
#  ['bottled beer', 'bottled water'],
#  ['pork', 'chocolate', 'soap'],
#  ['finished products',
#   'pip fruit',
#   'curd',
#   'pork',
#   'curd',
#   'whipped/sour cream',
#   'whole milk'],
#  ['UHT-milk', 'soda'],
#  ['chicken', 'herbs'],
#  ['soft cheese', 'white wine'],
#  ['frozen potato products', 'soda'],
#  ['tropical fruit', 'hygiene articles'],
#  ['chocolate', 'curd cheese'],
#  ['yogurt', 'whipped/sour cream'],
#  ['pastry', 'root vegetables'],
#  ['sausage', 'pip fruit'],
#  ['butter milk', 'beverages', 'butter'],
#  ['beef', 'other vegetables'],
#  ['sausage', 'semi-finished bread'],
#  ['frankfurter', 'root vegetables'],
#  ['rolls/buns', 'mayonnaise', 'flour'],
#  ['citrus fruit', 'citrus fruit', 'bottled water', 'pastry'],
#  ['finished products', 'UHT-milk'],
#  ['other vegetables', 'brown bread'],
#  ['whole milk', 'soft cheese', 'pastry'],
#  ['tropical fruit', 'bottled beer', 'other vegetables', 'oil'],
#  ['fruit/vegetable juice', 'bottled water'],
#  ['chocolate', 'tropical fruit'],
#  ['whole milk', 'pip fruit'],
#  ['pip fruit', 'root vegetables'],
#  ['tropical fruit',
#   'grapes',
#   'sausage',
#   'grapes',
#   'fruit/vegetable juice',
#   'curd',
#   'other vegetables',
#   'whipped/sour cream'],
#  ['mayonnaise', 'frozen vegetables', 'processed cheese'],
#  ['newspapers', 'margarine'],
#  ['pip fruit', 'tropical fruit', 'whole milk'],
#  ['rolls/buns', 'berries', 'meat spreads'],
#  ['other vegetables', 'spread cheese'],
#  ['sugar', 'popcorn', 'baking powder'],
#  ['tropical fruit', 'pastry'],
#  ['pork', 'rolls/buns'],
#  ['tropical fruit', 'whole milk', 'long life bakery product'],
#  ['pip fruit', 'frozen vegetables'],
#  ['hamburger meat', 'canned beer', 'other vegetables', 'canned fruit'],
#  ['whole milk', 'whipped/sour cream'],
#  ['whole milk', 'onions'],
#  ['meat', 'whipped/sour cream'],
#  ['pastry', 'candy'],
#  ['whole milk', 'berries', 'specialty chocolate', 'white bread'],
#  ['whole milk', 'bottled beer'],
#  ['baking powder', 'pet care', 'yogurt', 'frozen vegetables'],
#  ['whole milk',
#   'frankfurter',
#   'yogurt',
#   'pip fruit',
#   'dessert',
#   'soda',
#   'margarine'],
#  ['ham', 'berries'],
#  ['canned beer', 'soda', 'frozen vegetables'],
#  ['other vegetables', 'sliced cheese'],
#  ['frozen fish', 'curd'],
#  ['napkins', 'bottled beer'],
#  ['processed cheese', 'dishes'],
#  ['hamburger meat', 'coffee'],
#  ['shopping bags',
#   'pork',
#   'canned fish',
#   'whole milk',
#   'onions',
#   'bottled beer',
#   'canned beer'],
#  ['soda', 'cereals'],
#  ['other vegetables', 'whole milk', 'artif. sweetener'],
#  ['frozen vegetables', 'other vegetables'],
#  ['citrus fruit', 'rolls/buns'],
#  ['other vegetables', 'dish cleaner'],
#  ['pork', 'soda'],
#  ['tropical fruit', 'citrus fruit'],
#  ['shopping bags', 'pickled vegetables'],
#  ['canned beer', 'yogurt'],
#  ['other vegetables', 'soda'],
#  ['whole milk', 'seasonal products'],
#  ['hard cheese', 'margarine', 'rolls/buns'],
#  ['other vegetables', 'bottled beer'],
#  ['sausage', 'citrus fruit'],
#  ['sausage', 'fruit/vegetable juice'],
#  ['beef', 'brown bread'],
#  ['beef', 'whole milk', 'detergent'],
#  ['root vegetables', 'whole milk'],
#  ['salty snack', 'chocolate marshmallow'],
#  ['pip fruit', 'rolls/buns'],
#  ['whole milk', 'whole milk'],
#  ['berries', 'hamburger meat'],
#  ['butter milk', 'bottled water'],
#  ['bottled beer', 'grapes', 'other vegetables', 'bottled water'],
#  ['yogurt', 'flower (seeds)'],
#  ['rolls/buns', 'whole milk'],
#  ['sausage', 'yogurt'],
#  ['pastry', 'rolls/buns'],
#  ['tropical fruit', 'pip fruit', 'root vegetables', 'pet care'],
#  ['soda', 'bottled beer'],
#  ['other vegetables', 'yogurt'],
#  ['frankfurter',
#   'berries',
#   'bottled water',
#   'processed cheese',
#   'pickled vegetables'],
#  ['frankfurter', 'soda', 'canned beer', 'white bread', 'brown bread'],
#  ['ham', 'newspapers', 'bottled beer'],
#  ['citrus fruit', 'sauces'],
#  ['rolls/buns',
#   'misc. beverages',
#   'ice cream',
#   'tropical fruit',
#   'shopping bags',
#   'coffee',
#   'popcorn',
#   'hygiene articles'],
#  ['bottled beer', 'sparkling wine', 'hamburger meat', 'rolls/buns'],
#  ['rolls/buns', 'cereals'],
#  ['grapes', 'cream cheese '],
#  ['beef', 'other vegetables'],
#  ['yogurt', 'hamburger meat', 'other vegetables', 'mustard'],
#  ['frankfurter', 'coffee'],
#  ['dessert', 'photo/film'],
#  ['domestic eggs', 'mayonnaise'],
#  ['other vegetables', 'yogurt'],
#  ['soda', 'whole milk', 'soda', 'specialty bar', 'bottled water'],
#  ['yogurt', 'soda'],
#  ['UHT-milk', 'other vegetables'],
#  ['packaged fruit/vegetables', 'rolls/buns', 'domestic eggs'],
#  ['dessert', 'brown bread'],
#  ['dessert', 'frozen vegetables'],
#  ['whole milk', 'cake bar'],
#  ['other vegetables', 'white bread', 'soft cheese'],
#  ['yogurt', 'bottled water'],
#  ['ice cream', 'yogurt', 'oil'],
#  ['sugar', 'berries'],
#  ['dog food', 'coffee', 'seasonal products'],
#  ['waffles', 'chocolate'],
#  ['tropical fruit', 'frozen meals', 'fruit/vegetable juice'],
#  ['sausage', 'other vegetables'],
#  ['sausage', 'beef', 'white wine', 'other vegetables'],
#  ['tropical fruit', 'hard cheese'],
#  ['citrus fruit', 'bottled beer', 'roll products '],
#  ['dessert', 'yogurt'],
#  ['other vegetables', 'margarine'],
#  ['ham', 'salt'],
#  ['other vegetables', 'cake bar'],
#  ['sugar', 'whole milk'],
#  ...]

# %%
te = TransactionEncoder() # we use the Transaction Encoder of mlxtend for it
te_ary = te.fit(transSummer).transform(transSummer)
transactions = pd.DataFrame(te_ary, columns=te.columns_) # encode the transaction

# %%
freq_items = apriori(transactions, min_support=0.001, use_colnames=True, verbose=1)
freq_items.head(7)
# Out:
# Processing 132 combinations | Sampling itemset size 4 3
#     support                 itemsets
# 0  0.003627  (Instant food products)
# 1  0.023575               (UHT-milk)
# 2  0.001554       (abrasive cleaner)
# 3  0.002073       (artif. sweetener)
# 4  0.008808          (baking powder)
# 5  0.001554       (bathroom cleaner)
# 6  0.034456                   (beef)

# %%
freq_items['length'] = freq_items['itemsets'].apply(lambda x: len(x))

# %%
number_of_items = freq_items.shape[0]
freq_items.sort_values('length',ascending=False) # we get the number of times the number of itemsets' frequency
# Out:
#       support                                     itemsets  length
# 900  0.001295                  (soda, whole milk, sausage)       3
# 889  0.001036      (whole milk, other vegetables, sausage)       3
# 878  0.001295            (soda, whole milk, bottled water)       3
# 879  0.001036  (hygiene articles, whole milk, canned beer)       3
# 880  0.001036              (soda, whole milk, canned beer)       3
# ..        ...                                          ...     ...
# 97   0.038342                                       (pork)       1
# 96   0.003627                                    (popcorn)       1
# 95   0.047409                                  (pip fruit)       1
# 94   0.011399                         (pickled vegetables)       1
# 0    0.003627                      (Instant food products)       1
#
# [901 rows x 3 columns]

# %%
number_of_items
# Out:
# 901

# %%
rules = association_rules(freq_items, metric="lift", min_threshold=0.001)
rules.head()
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0       (UHT-milk)  (bottled water)            0.023575            0.056736
# 1  (bottled water)       (UHT-milk)            0.056736            0.023575
# 2  (cream cheese )       (UHT-milk)            0.026684            0.023575
# 3       (UHT-milk)  (cream cheese )            0.023575            0.026684
# 4           (curd)       (UHT-milk)            0.032902            0.023575
#
#     support  confidence      lift  leverage  conviction
# 0  0.001295    0.054945  0.968438 -0.000042    0.998105
# 1  0.001295    0.022831  0.968438 -0.000042    0.999239
# 2  0.001554    0.058252  2.470927  0.000925    1.036822
# 3  0.001554    0.065934  2.470927  0.000925    1.042021
# 4  0.001295    0.039370  1.669984  0.000520    1.016442

# %%
rules.sort_values('lift', ascending=False) # this is what our rules must look 
# like when applied using the mlxtend package
# Out:
#                          antecedents                     consequents  \
# 1475              (hygiene articles)       (whole milk, canned beer)
# 1474       (whole milk, canned beer)              (hygiene articles)
# 1472  (whole milk, hygiene articles)                   (canned beer)
# 1477                   (canned beer)  (whole milk, hygiene articles)
# 1500                     (margarine)               (yogurt, sausage)
# ...                              ...                             ...
# 1084                    (newspapers)                          (soda)
# 609                         (coffee)                          (soda)
# 608                           (soda)                        (coffee)
# 67                            (beef)                          (soda)
# 66                            (soda)                          (beef)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 1475            0.017358            0.006218  0.001036    0.059701  9.601990
# 1474            0.006218            0.017358  0.001036    0.166667  9.601990
# 1472            0.003109            0.046891  0.001036    0.333333  7.108656
# 1477            0.046891            0.003109  0.001036    0.022099  7.108656
# 1500            0.029534            0.005440  0.001036    0.035088  6.449457
# ...                  ...                 ...       ...         ...       ...
# 1084            0.040933            0.096114  0.001295    0.031646  0.329250
# 609             0.033938            0.096114  0.001036    0.030534  0.317689
# 608             0.096114            0.033938  0.001036    0.010782  0.317689
# 67              0.034456            0.096114  0.001036    0.030075  0.312912
# 66              0.096114            0.034456  0.001036    0.010782  0.312912
#
#       leverage  conviction
# 1475  0.000928    1.056880
# 1474  0.000928    1.179171
# 1472  0.000890    1.429663
# 1477  0.000890    1.019420
# 1500  0.000876    1.030725
# ...        ...         ...
# 1084 -0.002639    0.933425
# 609  -0.002226    0.932355
# 608  -0.002226    0.976591
# 67   -0.002275    0.931913
# 66   -0.002275    0.976068
#
# [1604 rows x 9 columns]

# %% [markdown]
# # Part 4: Building our 4 Sets of Association Rules
#
# We can now move on to building our 4 sets of association rules, one for each season. We do by building a custom function with which we can make our association rule analysis.
#
# It is important to note that we first want to fixate the minimum support an association rule needs to be considered in our set. The smaller our minimum support threshold, the more rule we will get and the less siginificant will be our findings.

# %%
Spring = 0 # we encode each of our Season by it's happeing per months
Summer = 1
Fall   = 2
Winter = 3

# %%
min_support = 0.001 # HyperParameters
min_threshold = 0.001

# %%
def analysisMaker(dataFrameBasket,min_support=min_support,min_threshold=min_threshold):
    dataFrameBasket.fillna('!',inplace=True)
    valuesBasket = dataFrameBasket.values.tolist()
    for i in range(len(valuesBasket)):
        valuesBasket[i] = [x for x in valuesBasket[i] if not x=='!']

    te = TransactionEncoder()
    te_ary = te.fit(valuesBasket).transform(valuesBasket)
    transactions = pd.DataFrame(te_ary, columns=te.columns_)

    freq_items = apriori(transactions, min_support=min_support, use_colnames=True, verbose=1)
    freq_items.head(7)
    print('apriori:', freq_items.shape)

    freq_items['length'] = freq_items['itemsets'].apply(lambda x: len(x))
    freq_items.sort_values('length',ascending=False)

    rules = association_rules(freq_items, metric="lift", min_threshold=min_threshold)
    rules.head()
    print('rules:', rules.shape)

    rules.sort_values('lift', ascending=False)
    return rules

# %%
baskets = np.array([basketSpring,basketSummer,basketFall,basketWinter],dtype=object)
# first consider our baskets, that is an array of basket, 1 per season

# %%
def rulesCV(baskets,min_support=min_support,min_threshold=min_threshold): # we make CV fold of the association rules
    
    rulesMainFold = [] # this will be the list of our MainFolds
    rulesTestFold = [] # this will the list of our Test Folds
    for basket in range(len(baskets)):
        concatenatedBasket = pd.concat(np.array(np.delete(baskets, basket),dtype=object))
        # concatenate our "MainFold"
    
        print(tuple(map(sum, zip(concatenatedBasket.shape, baskets[basket].shape))))
        # this print statement helps us visualize that all transactions are taken into the account in the list makers
        mainFold = analysisMaker(concatenatedBasket,min_support=min_support,min_threshold=min_threshold)
        testFold = analysisMaker(baskets[basket],min_support=min_support,min_threshold=min_threshold) 
        rulesMainFold.append(mainFold) # we append the Main Fold for each season to the Main Fold list
        rulesTestFold.append(testFold)
        
  
    return rulesMainFold, rulesTestFold

# %%
# val = analysisMaker(basketFall)
# val.sort_values('support', ascending=False)

rulesMainFold, rulesTestFold = rulesCV(baskets)
# Out:
# (14963, 20)
# Processing 16 combinations | Sampling itemset size 4e 3
# apriori: (714, 2)
# rules: (1158, 9)
# Processing 168 combinations | Sampling itemset size 4 3
# apriori: (873, 2)
# rules: (1596, 9)
# (14963, 20)
# Processing 12 combinations | Sampling itemset size 4e 3
# apriori: (696, 2)
# rules: (1124, 9)
# Processing 132 combinations | Sampling itemset size 4 3
# apriori: (901, 2)
# rules: (1604, 9)
# (14963, 20)
# Processing 48 combinations | Sampling itemset size 4e 3
# apriori: (711, 2)
# rules: (1174, 9)
# Processing 220 combinations | Sampling itemset size 4 3
# apriori: (835, 2)
# rules: (1474, 9)
# (14963, 20)
# Processing 24 combinations | Sampling itemset size 4e 3
# apriori: (732, 2)
# rules: (1206, 9)
# Processing 124 combinations | Sampling itemset size 4 3
# apriori: (784, 2)
# rules: (1358, 9)

# %%
rulesMainFold[0]
# Out:
#                antecedents           consequents  antecedent support  \
# 0               (UHT-milk)        (bottled beer)            0.020146
# 1           (bottled beer)            (UHT-milk)            0.046354
# 2               (UHT-milk)       (bottled water)            0.020146
# 3          (bottled water)            (UHT-milk)            0.058745
# 4               (UHT-milk)    (other vegetables)            0.020146
# ...                    ...                   ...                 ...
# 1153        (soda, yogurt)          (whole milk)            0.005794
# 1154  (yogurt, whole milk)                (soda)            0.010073
# 1155                (soda)  (yogurt, whole milk)            0.097700
# 1156          (whole milk)        (soda, yogurt)            0.155910
# 1157              (yogurt)    (soda, whole milk)            0.083437
#
#       consequent support   support  confidence      lift  leverage  conviction
# 0               0.046354  0.001070    0.053097  1.145473  0.000136    1.007121
# 1               0.020146  0.001070    0.023077  1.145473  0.000136    1.003000
# 2               0.058745  0.001070    0.053097  0.903863 -0.000114    0.994036
# 3               0.020146  0.001070    0.018209  0.903863 -0.000114    0.998027
# 4               0.124443  0.002050    0.101770  0.817804 -0.000457    0.974758
# ...                  ...       ...         ...       ...       ...         ...
# 1153            0.155910  0.001159    0.200000  1.282790  0.000255    1.055112
# 1154            0.097700  0.001159    0.115044  1.177524  0.000175    1.019599
# 1155            0.010073  0.001159    0.011861  1.177524  0.000175    1.001810
# 1156            0.005794  0.001159    0.007433  1.282790  0.000255    1.001651
# 1157            0.011767  0.001159    0.013889  1.180345  0.000177    1.002152
#
# [1158 rows x 9 columns]

# %%
rulesTestFold[0]
# Out:
#                        antecedents                   consequents  \
# 0          (Instant food products)                  (whole milk)
# 1                     (whole milk)       (Instant food products)
# 2                       (UHT-milk)               (bottled water)
# 3                  (bottled water)                    (UHT-milk)
# 4                       (UHT-milk)                 (canned beer)
# ...                            ...                           ...
# 1591          (yogurt, whole milk)              (tropical fruit)
# 1592  (whole milk, tropical fruit)                      (yogurt)
# 1593                      (yogurt)  (whole milk, tropical fruit)
# 1594              (tropical fruit)          (yogurt, whole milk)
# 1595                  (whole milk)      (yogurt, tropical fruit)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 0               0.003738            0.163952  0.001068    0.285714  1.742671
# 1               0.163952            0.003738  0.001068    0.006515  1.742671
# 2               0.025100            0.066489  0.001068    0.042553  0.640007
# 3               0.066489            0.025100  0.001068    0.016064  0.640007
# 4               0.025100            0.049933  0.001068    0.042553  0.852202
# ...                  ...                 ...       ...         ...       ...
# 1591            0.014419            0.073698  0.001602    0.111111  1.507649
# 1592            0.010681            0.093191  0.001602    0.150000  1.609599
# 1593            0.093191            0.010681  0.001602    0.017192  1.609599
# 1594            0.073698            0.014419  0.001602    0.021739  1.507649
# 1595            0.163952            0.006943  0.001602    0.009772  1.407542
#
#       leverage  conviction
# 0     0.000455    1.170467
# 1     0.000455    1.002795
# 2    -0.000601    0.975001
# 3    -0.000601    0.990817
# 4    -0.000185    0.992292
# ...        ...         ...
# 1591  0.000539    1.042089
# 1592  0.000607    1.066834
# 1593  0.000607    1.006625
# 1594  0.000539    1.007483
# 1595  0.000464    1.002857
#
# [1596 rows x 9 columns]

# %% [markdown]
# # Part 5: Chi-Square Testing
#
#
# We must now do chi-square testing to see whether we have siginificant differences between the different rules. obtained, and see if there's bundles that ùre affected by seasonality

# %% [markdown]
# how do I test the p-value on the apriori algorithm?
#
#
# The p-value is a measure of statistical significance that is used to determine whether the results of a hypothesis test are reliable. In the context of the Apriori algorithm, the p-value is used to determine the support for each itemset in the dataset.
#
# To test the p-value for an itemset using the Apriori algorithm, you can follow these steps:
#
# Set a minimum support threshold (min_support) and a minimum confidence threshold (min_confidence). The min_support threshold is the minimum number of occurrences of an itemset in the dataset for it to be considered "frequent", and the min_confidence threshold is the minimum probability that an itemset will be included in the final set of frequent itemsets.
#
# Use the Apriori algorithm to find all frequent itemsets in the dataset that meet the min_support threshold.
#
# For each frequent itemset, calculate the support and confidence of the itemset. The support of an itemset is the percentage of transactions in the dataset that contain the itemset, and the confidence of an itemset is the probability that an itemset will be included in the final set of frequent itemsets.
#
# Calculate the p-value for each frequent itemset using the formula: p-value = 1 - confidence.
#
# Compare the p-value for each frequent itemset to the min_confidence threshold. If the p-value is less than the min_confidence threshold, then the itemset is considered statistically significant and can be included in the final set of frequent itemsets. If the p-value is greater than the min_confidence threshold, then the itemset is not statistically significant and should not be included in the final set of frequent itemsets.
#
# I hope this helps! Let me know if you have any questions or need further clarification.

# %%
n = number_of_items # we will need the number of transactions for computing the Chi-Square Value
n
# Out:
# 901

# %%
rulesMainFold[0][['antecedents','consequents']] # this is the list of the rules of the main fold
# Out:
#                antecedents           consequents
# 0               (UHT-milk)        (bottled beer)
# 1           (bottled beer)            (UHT-milk)
# 2               (UHT-milk)       (bottled water)
# 3          (bottled water)            (UHT-milk)
# 4               (UHT-milk)    (other vegetables)
# ...                    ...                   ...
# 1153        (soda, yogurt)          (whole milk)
# 1154  (yogurt, whole milk)                (soda)
# 1155                (soda)  (yogurt, whole milk)
# 1156          (whole milk)        (soda, yogurt)
# 1157              (yogurt)    (soda, whole milk)
#
# [1158 rows x 2 columns]

# %%
def getDiffOverlap(rulesMainFold,rulesTestFold):
    dfSeason_DiffInTest = [] # dataframe where there's rule in Test not in 
     # main 
    dfSeason_DiffInMain = [] # dataframe where There's rule in Main not
    # in Test
    dfSeason_overlap = [] # dataframe where there's the rule present in 
    # both 


    for value in range(seasons):
        dfSeason_diff = pd.concat([rulesMainFold[value][['antecedents','consequents']], # we concatenate the rules
                                        rulesTestFold[value][['antecedents','consequents']]]).drop_duplicates(keep=False)

        dfSeason_overlap.append(pd.merge(rulesMainFold[value][['antecedents','consequents']],
                                     rulesTestFold[value][['antecedents','consequents']], 
                                     how='inner', on=['antecedents','consequents'])) # we append the overlap
                                    # using 'fake' SQL, in pandas

        dfSeason_DiffInMain.append(pd.merge(rulesMainFold[value][['antecedents','consequents']],
                                     dfSeason_diff,
                                     how='inner', on=['antecedents','consequents']))
                # we use this same fake SQl to fetch the rules in Main not in Test

        dfSeason_DiffInTest.append(pd.merge(dfSeason_diff,
                                     rulesTestFold[value][['antecedents','consequents']],
                                     how='inner', on=['antecedents','consequents']))
            # finally we get the rules that are in the tested season, but are not in the Main Fold

    return dfSeason_DiffInTest, dfSeason_DiffInMain, dfSeason_overlap

# %%
dfSeason_DiffInTest, dfSeason_DiffInMain, dfSeason_overlap = getDiffOverlap(rulesMainFold,rulesTestFold)
# we use the function Season

# %%
dfSeason_DiffInTest[0].shape[0]+dfSeason_overlap[0].shape[0]
# Out:
# 1596

# %%
rulesTestFold[0].shape[0]
# Out:
# 1596

# %%
dfSeason_DiffInMain[0].shape[0]+dfSeason_overlap[0].shape[0]
# Out:
# 1158

# %%
rulesMainFold[0].shape[0]
# Out:
# 1158

# %%
for val in range(seasons):
    print(rulesTestFold[val].shape[0]-rulesMainFold[val].shape[0]) # we print the difference in cardinalities
    # between the test and the main fold, we see that the test may have more or jsut as much association rules
# Out:
# 438
# 480
# 300
# 152

# %%
rulesTestFold[0] # this is the results for the test rule
# Out:
#                        antecedents                   consequents  \
# 0          (Instant food products)                  (whole milk)
# 1                     (whole milk)       (Instant food products)
# 2                       (UHT-milk)               (bottled water)
# 3                  (bottled water)                    (UHT-milk)
# 4                       (UHT-milk)                 (canned beer)
# ...                            ...                           ...
# 1591          (yogurt, whole milk)              (tropical fruit)
# 1592  (whole milk, tropical fruit)                      (yogurt)
# 1593                      (yogurt)  (whole milk, tropical fruit)
# 1594              (tropical fruit)          (yogurt, whole milk)
# 1595                  (whole milk)      (yogurt, tropical fruit)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 0               0.003738            0.163952  0.001068    0.285714  1.742671
# 1               0.163952            0.003738  0.001068    0.006515  1.742671
# 2               0.025100            0.066489  0.001068    0.042553  0.640007
# 3               0.066489            0.025100  0.001068    0.016064  0.640007
# 4               0.025100            0.049933  0.001068    0.042553  0.852202
# ...                  ...                 ...       ...         ...       ...
# 1591            0.014419            0.073698  0.001602    0.111111  1.507649
# 1592            0.010681            0.093191  0.001602    0.150000  1.609599
# 1593            0.093191            0.010681  0.001602    0.017192  1.609599
# 1594            0.073698            0.014419  0.001602    0.021739  1.507649
# 1595            0.163952            0.006943  0.001602    0.009772  1.407542
#
#       leverage  conviction
# 0     0.000455    1.170467
# 1     0.000455    1.002795
# 2    -0.000601    0.975001
# 3    -0.000601    0.990817
# 4    -0.000185    0.992292
# ...        ...         ...
# 1591  0.000539    1.042089
# 1592  0.000607    1.066834
# 1593  0.000607    1.006625
# 1594  0.000539    1.007483
# 1595  0.000464    1.002857
#
# [1596 rows x 9 columns]

# %%
df = rulesMainFold[0]
df.loc[df['leverage'] > 0.001]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
def ObservedContingencyTableRule(n,support, lift, confidence): # we build a list 
    # containg the probabilitie of the Observed Contigency Table
    AandB = n*support
    AandNotB = n*support/confidence*(1-confidence)
    NotAandB = n*(confidence/lift-support)
    NotAandNotB = n*(1-support/confidence*(1-confidence)-confidence/lift)
        # those probabilities are computed as Specfied in the Boston College Paper

    return [AandB,AandNotB,NotAandB,NotAandNotB]

# %%
def ExpectedContingencyTableRule(n,support, lift, confidence):
     # we build a list 
    # containg the probabilitie of the Expected Contigency Table

    AandB = n*support/lift
    AandNotB = n*support/confidence*(1-confidence/lift)
    NotAandB = n*(1-support/confidence)*(confidence/lift)
    NotAandNotB = n*(1-support/confidence)*(1-confidence/lift)
    # those probabilities are computed as Specfied in the Boston College Paper
    return [AandB,AandNotB,NotAandB,NotAandNotB]

# %%
def ChiSquareComputationReloaded(n,support, lift, confidence):
    ChiSquareValue = n*np.power((lift-1),2)*(support*confidence)/((confidence-support)*(lift-confidence))
    # those are a different type of chi-Square to use on a set of rules
    # we may need it but it's not the most useful
    return ChiSquareValue

# %%
def ChiSquareComputation(listObservedProbs,listExpectedProbs):
    assert len(listObservedProbs) == len(listExpectedProbs)
    # this is the main Chi_Square computation, the most useful, we will need it
    # to compare the set of rules
    # this is the computation for the Comparison
    ChiSquareValue = 0
    for value in range(len(listObservedProbs)):
        ChiSquareValue += ((np.power(listObservedProbs[value]-listExpectedProbs[value], 2))/listExpectedProbs[value])
        # we use the Chi-Square formula on each 4 of the probabilities, and
        #compare the observation, the test fold season, to the main, fold, the observed, the rest of the year
    return ChiSquareValue

# %%
antecedents = dfSeason_overlap[0]['antecedents'].iloc[1] # we get the antecents values
consequents = dfSeason_overlap[0]['consequents'].iloc[1] # we get the consequent vaues
# those come from the overlap table, the intermediate table, to see
# if the values are presernt in both tables


print(antecedents) # the antcents and consequents act the unique Key of a SQL, table
print(consequents)

MainFold = rulesMainFold[0]
TestFold = rulesTestFold[0] # we get the first season

MainRow = MainFold.loc[(MainFold['antecedents'] == antecedents) & (MainFold['consequents'] == consequents)]
# we get the row from the Main Fold
MainRow
# Out:
# frozenset({'bottled water'})
# frozenset({'UHT-milk'})
#        antecedents consequents  antecedent support  consequent support  \
# 3  (bottled water)  (UHT-milk)            0.058745            0.020146
#
#    support  confidence      lift  leverage  conviction
# 3  0.00107    0.018209  0.903863 -0.000114    0.998027

# %%
TestRow = TestFold.loc[(TestFold['antecedents'] == antecedents) & (TestFold['consequents'] == consequents)]
# we get the row from the test Fold
TestRow
# Out:
#        antecedents consequents  antecedent support  consequent support  \
# 3  (bottled water)  (UHT-milk)            0.066489              0.0251
#
#     support  confidence      lift  leverage  conviction
# 3  0.001068    0.016064  0.640007 -0.000601    0.990817

# %%
support = TestRow['support'].item() # we get our 3 KPIs
lift = TestRow['lift'].item()
confidence = TestRow['confidence'].item()

listObservedProbs = ObservedContingencyTableRule(n,support,lift,confidence)
# wecompute the list of the 4 probabilities as observed, the test
listObservedProbs
# Out:
# [0.9623497997329773, 58.94392523364487, 21.65287049399199, 819.4408544726302]

# %%
support = MainRow['support'].item() # same 3 KPIS
lift = MainRow['lift'].item()
confidence = MainRow['confidence'].item()

listExpectedProbs = ExpectedContingencyTableRule(n,support,lift,confidence)
# wecompute the list of the 4 probabilities as expected, the main

listExpectedProbs
# Out:
# [1.0663205362875885, 51.86281121625298, 17.085399912990358, 830.9854683344691]

# %%
ChiSquareComputation(listObservedProbs,listExpectedProbs) # we compute the CHi Square!
# Out:
# 2.3583766161044

# %%
# we now loop through the overlaps for each test season

def AssociationRulesClassification(dfSeason_overlap,rulesMainFold,rulesTestFold):
    for season in range(seasons):
        df = rulesTestFold[season]
        df.reset_index()
        # we add those value
        # df['Chi-Square-Test'] = 0 # those values are just to see if there's an issue with the data
        # df['Chi-Square-Main'] = 0
 
        TestFold = rulesTestFold[season] # we get the test rules
        MainFold = rulesMainFold[season] # we get the main fold of the season




        # if DIFF CONFIDENCE is NEGATIVE then the  rule did WORSE on the tested Season
        # some times Diff lift and confidence, dont'have the same sign, i dont know why

        for rules in range(len(rulesTestFold[season])): # we loop through the rules
            
            TestRow = TestFold.iloc[rules]
            # we get the row in the test fold associated with this rule

            supportTest = TestRow['support'].item() # we get the test support 
            liftTest = TestRow['lift'].item() # test lift 
            confidenceTest = TestRow['confidence'].item() # test confidence


            value = ChiSquareComputationReloaded(n,supportTest,liftTest,confidenceTest) 
            
            df.loc[rules, ['Chi-Square-Test']]= value


            # df.loc[rules, ['Difference Leverage']]= leverageTest - leverageMain 
            # we can compare if the rule did better

# %%
AssociationRulesClassification(dfSeason_overlap,rulesMainFold,rulesTestFold)

# %%
rulesTestFold[0].loc[rulesTestFold[0][['Chi-Square-Test']].idxmax()] # we get the highest Chi Suqare in 
# Spring
# Out:
#       antecedents              consequents  antecedent support  \
# 1469  (ice cream)  (rolls/buns, pip fruit)            0.015754
#
#       consequent support   support  confidence       lift  leverage  \
# 1469            0.006943  0.001335    0.084746  12.206649  0.001226
#
#       conviction  Chi-Square-Test
# 1469    1.085007        12.662522

# %%
rulesTestFold[1].loc[rulesTestFold[1][['Chi-Square-Test']].idxmax()] # highest Chi square in summer
# Out:
#                     antecedents         consequents  antecedent support  \
# 1474  (whole milk, canned beer)  (hygiene articles)            0.006218
#
#       consequent support   support  confidence     lift  leverage  conviction  \
# 1474            0.017358  0.001036    0.166667  9.60199  0.000928    1.179171
#
#       Chi-Square-Test
# 1474          7.36796

# %%
rulesTestFold[2].loc[rulesTestFold[2][['Chi-Square-Test']].idxmax()]
# Out:
#             antecedents consequents  antecedent support  consequent support  \
# 1368  (coffee, sausage)    (pastry)             0.00136            0.050598
#
#        support  confidence       lift  leverage  conviction  Chi-Square-Test
# 1368  0.001088         0.8  15.810753  0.001019    4.747008        14.346706

# %%
rulesTestFold[3].loc[rulesTestFold[3][['Chi-Square-Test']].idxmax()]
# Out:
#                          antecedents consequents  antecedent support  \
# 1304  (whole milk, other vegetables)   (waffles)            0.010864
#
#       consequent support   support  confidence      lift  leverage  \
# 1304            0.022542  0.001358       0.125  5.545181  0.001113
#
#       conviction  Chi-Square-Test
# 1304    1.117095         4.714584

# %%
rulesTestFold[2].loc[rulesTestFold[2][['Chi-Square-Test']].idxmax()]
# Out:
#             antecedents consequents  antecedent support  consequent support  \
# 1368  (coffee, sausage)    (pastry)             0.00136            0.050598
#
#        support  confidence       lift  leverage  conviction  Chi-Square-Test
# 1368  0.001088         0.8  15.810753  0.001019    4.747008        14.346706

# %% [markdown]
# ## Chi-Square Computation
#
# We must write note that the Chi-Square in this figure has a single degree of freedom, as the rule A->B is considered a random binary variable, (on whether it exist or not). Therefore, we

# %% [markdown]
# # Part 6: Analysis of the rules
#
# We can now separate the rules into 4 categories:
# -
#
# It is important to note that we use The Critical value of the Chi-Square given we have 1 degree of freedom, when using it on association rule set, as explain by Sergio Alvarez.

# %%
ChiSquareCriticalValue90 = 2.706 # 0.9 STATISTICAL SIGNIFICANCE
ChiSquareCriticalValue95 = 3.841 # 0.95 STATISTICAL SIGNIFICANCE

# %%
df = rulesTestFold[0]
df.loc[(df['Chi-Square-Test'] >= ChiSquareCriticalValue90)]
# Out:
#                       antecedents                  consequents  \
# 44                (baking powder)                (canned beer)
# 45                  (canned beer)              (baking powder)
# 350    (long life bakery product)                (butter milk)
# 351                 (butter milk)   (long life bakery product)
# 376               (specialty bar)                      (candy)
# 377                       (candy)              (specialty bar)
# 780         (specialty chocolate)               (frozen meals)
# 781                (frozen meals)        (specialty chocolate)
# 882                 (hard cheese)                (soft cheese)
# 883                 (soft cheese)                (hard cheese)
# 1422        (yogurt, frankfurter)               (citrus fruit)
# 1423       (yogurt, citrus fruit)                (frankfurter)
# 1424  (frankfurter, citrus fruit)                     (yogurt)
# 1425                     (yogurt)  (frankfurter, citrus fruit)
# 1426                (frankfurter)       (yogurt, citrus fruit)
# 1427               (citrus fruit)        (yogurt, frankfurter)
# 1436            (yogurt, sausage)                       (curd)
# 1437                       (curd)            (yogurt, sausage)
# 1464      (rolls/buns, pip fruit)                  (ice cream)
# 1465      (rolls/buns, ice cream)                  (pip fruit)
# 1466       (pip fruit, ice cream)                 (rolls/buns)
# 1467                 (rolls/buns)       (pip fruit, ice cream)
# 1468                  (pip fruit)      (rolls/buns, ice cream)
# 1469                  (ice cream)      (rolls/buns, pip fruit)
#
#       antecedent support  consequent support   support  confidence       lift  \
# 44              0.009613            0.049933  0.001869    0.194444   3.894088
# 45              0.049933            0.009613  0.001869    0.037433   3.894088
# 350             0.019226            0.015754  0.001335    0.069444   4.407957
# 351             0.015754            0.019226  0.001335    0.084746   4.407957
# 376             0.014686            0.014686  0.001068    0.072727   4.952066
# 377             0.014686            0.014686  0.001068    0.072727   4.952066
# 780             0.015754            0.020828  0.001335    0.084746   4.068883
# 781             0.020828            0.015754  0.001335    0.064103   4.068883
# 882             0.014419            0.011482  0.001068    0.074074   6.451335
# 883             0.011482            0.014419  0.001068    0.093023   6.451335
# 1422            0.002937            0.055274  0.001068    0.363636   6.578832
# 1423            0.005607            0.034980  0.001068    0.190476   5.445293
# 1424            0.001602            0.093191  0.001068    0.666667   7.153773
# 1425            0.093191            0.001602  0.001068    0.011461   7.153773
# 1426            0.034980            0.005607  0.001068    0.030534   5.445293
# 1427            0.055274            0.002937  0.001068    0.019324   6.578832
# 1436            0.006409            0.035247  0.001068    0.166667   4.728535
# 1437            0.035247            0.006409  0.001068    0.030303   4.728535
# 1464            0.006943            0.015754  0.001335    0.192308  12.206649
# 1465            0.002670            0.051535  0.001335    0.500000   9.702073
# 1466            0.001335            0.105474  0.001335    1.000000   9.481013
# 1467            0.105474            0.001335  0.001335    0.012658   9.481013
# 1468            0.051535            0.002670  0.001335    0.025907   9.702073
# 1469            0.015754            0.006943  0.001335    0.084746  12.206649
#
#       leverage  conviction  Chi-Square-Test
# 44    0.001389    1.179393         3.849724
# 45    0.001389    1.028902         3.849724
# 350   0.001032    1.057697         3.283380
# 351   0.001032    1.071587         3.283380
# 376   0.000852    1.062593         3.126409
# 377   0.000852    1.062593         3.126409
# 780   0.001007    1.069836         2.889122
# 781   0.001007    1.051660         2.889122
# 882   0.000903    1.067599         4.550009
# 883   0.000903    1.086666         4.550009
# 1422  0.000906    1.484570         4.833283
# 1423  0.000872    1.192084         3.639303
# 1424  0.000919    2.720427         5.626797
# 1425  0.000919    1.009973         5.626797
# 1426  0.000872    1.025712         3.639303
# 1427  0.000906    1.016709         4.833283
# 1436  0.000842    1.157704         2.951609
# 1437  0.000842    1.024641         2.951609
# 1464  0.001226    1.218590        12.662522
# 1465  0.001198    1.896929         9.925764
# 1466  0.001194         inf        10.215765
# 1467  0.001194    1.011468        10.215765
# 1468  0.001198    1.023855         9.925764
# 1469  0.001226    1.085007        12.662522

# %%
df = rulesTestFold[1]
df.loc[(df['Chi-Square-Test'] >= ChiSquareCriticalValue90)]
# Out:
#                            antecedents                       consequents  \
# 124                       (white wine)                       (beverages)
# 125                        (beverages)                      (white wine)
# 202                          (cereals)                   (bottled water)
# 203                    (bottled water)                         (cereals)
# 1048                         (napkins)                          (pastry)
# 1049                          (pastry)                         (napkins)
# 1472    (whole milk, hygiene articles)                     (canned beer)
# 1474         (whole milk, canned beer)                (hygiene articles)
# 1475                (hygiene articles)         (whole milk, canned beer)
# 1477                     (canned beer)    (whole milk, hygiene articles)
# 1496               (yogurt, margarine)                         (sausage)
# 1497                 (yogurt, sausage)                       (margarine)
# 1498              (margarine, sausage)                          (yogurt)
# 1499                          (yogurt)              (margarine, sausage)
# 1500                       (margarine)                 (yogurt, sausage)
# 1501                         (sausage)               (yogurt, margarine)
# 1580  (whipped/sour cream, rolls/buns)                          (yogurt)
# 1581      (whipped/sour cream, yogurt)                      (rolls/buns)
# 1582              (rolls/buns, yogurt)              (whipped/sour cream)
# 1583              (whipped/sour cream)              (rolls/buns, yogurt)
# 1584                      (rolls/buns)      (whipped/sour cream, yogurt)
# 1585                          (yogurt)  (whipped/sour cream, rolls/buns)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 124             0.012694            0.015544  0.001036    0.081633  5.251701
# 125             0.015544            0.012694  0.001036    0.066667  5.251701
# 202             0.003109            0.056736  0.001036    0.333333  5.875190
# 203             0.056736            0.003109  0.001036    0.018265  5.875190
# 1048            0.022539            0.055959  0.003627    0.160920  2.875692
# 1049            0.055959            0.022539  0.003627    0.064815  2.875692
# 1472            0.003109            0.046891  0.001036    0.333333  7.108656
# 1474            0.006218            0.017358  0.001036    0.166667  9.601990
# 1475            0.017358            0.006218  0.001036    0.059701  9.601990
# 1477            0.046891            0.003109  0.001036    0.022099  7.108656
# 1496            0.003368            0.061917  0.001036    0.307692  4.969424
# 1497            0.005440            0.029534  0.001036    0.190476  6.449457
# 1498            0.002850            0.082124  0.001036    0.363636  4.427875
# 1499            0.082124            0.002850  0.001036    0.012618  4.427875
# 1500            0.029534            0.005440  0.001036    0.035088  6.449457
# 1501            0.061917            0.003368  0.001036    0.016736  4.969424
# 1580            0.004145            0.082124  0.001554    0.375000  4.566246
# 1581            0.003109            0.107254  0.001554    0.500000  4.661836
# 1582            0.006995            0.042746  0.001554    0.222222  5.198653
# 1583            0.042746            0.006995  0.001554    0.036364  5.198653
# 1584            0.107254            0.003109  0.001554    0.014493  4.661836
# 1585            0.082124            0.004145  0.001554    0.018927  4.566246
#
#       leverage  conviction  Chi-Square-Test
# 124   0.000839    1.071963         3.306549
# 125   0.000839    1.057828         3.306549
# 202   0.000860    1.414896         4.016775
# 203   0.000860    1.015438         4.016775
# 1048  0.002366    1.125090         4.332670
# 1049  0.002366    1.045206         4.332670
# 1472  0.000890    1.429663         5.158353
# 1474  0.000928    1.179171         7.367960
# 1475  0.000928    1.056880         7.367960
# 1477  0.000890    1.019420         5.158353
# 1496  0.000828    1.355009         3.166433
# 1497  0.000876    1.198811         4.454198
# 1498  0.000802    1.442376         2.707121
# 1499  0.000802    1.009893         2.707121
# 1500  0.000876    1.030725         4.454198
# 1501  0.000828    1.013596         3.166433
# 1580  0.001214    1.468601         4.267486
# 1581  0.001221    1.785492         4.526409
# 1582  0.001255    1.230755         4.996193
# 1583  0.001255    1.030477         4.996193
# 1584  0.001221    1.011551         4.526409
# 1585  0.001214    1.015068         4.267486

# %%
df = rulesTestFold[2]
df.loc[(df['Chi-Square-Test'] >= ChiSquareCriticalValue90)]
# Out:
#                                 antecedents  \
# 484             (packaged fruit/vegetables)
# 485                             (chocolate)
# 596                                (pastry)
# 597                        (condensed milk)
# 706                               (mustard)
# 707                           (frankfurter)
# 1032                           (rolls/buns)
# 1033                     (other vegetables)
# 1072                                (pasta)
# 1073                              (sausage)
# 1190                   (whipped/sour cream)
# 1191                           (rolls/buns)
# 1324                (whole milk, chocolate)
# 1325             (whole milk, bottled beer)
# 1328                            (chocolate)
# 1329                         (bottled beer)
# 1342               (brown bread, pip fruit)
# 1343             (brown bread, frankfurter)
# 1344               (pip fruit, frankfurter)
# 1345                          (brown bread)
# 1346                            (pip fruit)
# 1347                          (frankfurter)
# 1348  (other vegetables, frozen vegetables)
# 1349       (other vegetables, citrus fruit)
# 1352                    (frozen vegetables)
# 1353                         (citrus fruit)
# 1366                       (pastry, coffee)
# 1367                      (pastry, sausage)
# 1368                      (coffee, sausage)
# 1369                               (pastry)
# 1370                               (coffee)
# 1371                              (sausage)
# 1420                         (pork, yogurt)
# 1421                        (pork, sausage)
# 1424                               (yogurt)
# 1425                              (sausage)
# 1444                (soda, root vegetables)
# 1445                        (soda, sausage)
# 1446             (root vegetables, sausage)
# 1447                                 (soda)
# 1448                      (root vegetables)
# 1449                              (sausage)
# 1456                   (yogurt, whole milk)
# 1458                  (whole milk, sausage)
# 1459                               (yogurt)
# 1461                              (sausage)
#
#                                 consequents  antecedent support  \
# 484                             (chocolate)            0.010065
# 485             (packaged fruit/vegetables)            0.022851
# 596                        (condensed milk)            0.050598
# 597                                (pastry)            0.004353
# 706                           (frankfurter)            0.006257
# 707                               (mustard)            0.039717
# 1032                     (other vegetables)            0.115887
# 1033                           (rolls/buns)            0.123504
# 1072                              (sausage)            0.006257
# 1073                                (pasta)            0.053319
# 1190                           (rolls/buns)            0.042165
# 1191                   (whipped/sour cream)            0.115887
# 1324                         (bottled beer)            0.003808
# 1325                            (chocolate)            0.008705
# 1328             (whole milk, bottled beer)            0.022851
# 1329                (whole milk, chocolate)            0.046246
# 1342                          (frankfurter)            0.002176
# 1343                            (pip fruit)            0.002176
# 1344                          (brown bread)            0.002992
# 1345               (pip fruit, frankfurter)            0.037813
# 1346             (brown bread, frankfurter)            0.048422
# 1347               (brown bread, pip fruit)            0.039717
# 1348                         (citrus fruit)            0.004353
# 1349                    (frozen vegetables)            0.003808
# 1352       (other vegetables, citrus fruit)            0.028020
# 1353  (other vegetables, frozen vegetables)            0.053319
# 1366                              (sausage)            0.001904
# 1367                               (coffee)            0.003264
# 1368                               (pastry)            0.001360
# 1369                      (coffee, sausage)            0.050598
# 1370                      (pastry, sausage)            0.033188
# 1371                       (pastry, coffee)            0.053319
# 1420                              (sausage)            0.004081
# 1421                               (yogurt)            0.001904
# 1424                        (pork, sausage)            0.088955
# 1425                         (pork, yogurt)            0.053319
# 1444                              (sausage)            0.005985
# 1445                      (root vegetables)            0.006257
# 1446                                 (soda)            0.002992
# 1447             (root vegetables, sausage)            0.099837
# 1448                        (soda, sausage)            0.075082
# 1449                (soda, root vegetables)            0.053319
# 1456                              (sausage)            0.010337
# 1458                               (yogurt)            0.007617
# 1459                  (whole milk, sausage)            0.088955
# 1461                   (yogurt, whole milk)            0.053319
#
#       consequent support   support  confidence       lift  leverage  \
# 484             0.022851  0.001088    0.108108   4.731017  0.000858
# 485             0.010065  0.001088    0.047619   4.731017  0.000858
# 596             0.004353  0.001088    0.021505   4.940860  0.000868
# 597             0.050598  0.001088    0.250000   4.940860  0.000868
# 706             0.039717  0.001904    0.304348   7.662895  0.001656
# 707             0.006257  0.001904    0.047945   7.662895  0.001656
# 1032            0.123504  0.008161    0.070423   0.570205 -0.006151
# 1033            0.115887  0.008161    0.066079   0.570205 -0.006151
# 1072            0.053319  0.001360    0.217391   4.077196  0.001027
# 1073            0.006257  0.001360    0.025510   4.077196  0.001027
# 1190            0.115887  0.001360    0.032258   0.278358 -0.003526
# 1191            0.042165  0.001360    0.011737   0.278358 -0.003526
# 1324            0.046246  0.001088    0.285714   6.178151  0.000912
# 1325            0.022851  0.001088    0.125000   5.470238  0.000889
# 1328            0.008705  0.001088    0.047619   5.470238  0.000889
# 1329            0.003808  0.001088    0.023529   6.178151  0.000912
# 1342            0.039717  0.001088    0.500000  12.589041  0.001002
# 1343            0.048422  0.001088    0.500000  10.325843  0.000983
# 1344            0.037813  0.001088    0.363636   9.616743  0.000975
# 1345            0.002992  0.001088    0.028777   9.616743  0.000975
# 1346            0.002176  0.001088    0.022472  10.325843  0.000983
# 1347            0.002176  0.001088    0.027397  12.589041  0.001002
# 1348            0.053319  0.001088    0.250000   4.688776  0.000856
# 1349            0.028020  0.001088    0.285714  10.196949  0.000981
# 1352            0.003808  0.001088    0.038835  10.196949  0.000981
# 1353            0.004353  0.001088    0.020408   4.688776  0.000856
# 1366            0.053319  0.001088    0.571429  10.717201  0.000987
# 1367            0.033188  0.001088    0.333333  10.043716  0.000980
# 1368            0.050598  0.001088    0.800000  15.810753  0.001019
# 1369            0.001360  0.001088    0.021505  15.810753  0.001019
# 1370            0.003264  0.001088    0.032787  10.043716  0.000980
# 1371            0.001904  0.001088    0.020408  10.717201  0.000987
# 1420            0.053319  0.001088    0.266667   5.001361  0.000871
# 1421            0.088955  0.001088    0.571429   6.423766  0.000919
# 1424            0.001904  0.001088    0.012232   6.423766  0.000919
# 1425            0.004081  0.001088    0.020408   5.001361  0.000871
# 1444            0.053319  0.001632    0.272727   5.115028  0.001313
# 1445            0.075082  0.001632    0.260870   3.474480  0.001162
# 1446            0.099837  0.001632    0.545455   5.463463  0.001333
# 1447            0.002992  0.001632    0.016349   5.463463  0.001333
# 1448            0.006257  0.001632    0.021739   3.474480  0.001162
# 1449            0.005985  0.001632    0.030612   5.115028  0.001313
# 1456            0.053319  0.002176    0.210526   3.948443  0.001625
# 1458            0.088955  0.002176    0.285714   3.211883  0.001499
# 1459            0.007617  0.002176    0.024465   3.211883  0.001499
# 1461            0.010337  0.002176    0.040816   3.948443  0.001625
#
#       conviction  Chi-Square-Test
# 484     1.095591         2.982235
# 485     1.039431         2.982235
# 596     1.017530         3.260118
# 597     1.265869         3.260118
# 706     1.380407        10.416144
# 707     1.043788        10.416144
# 1032    0.942897         3.073996
# 1033    0.946668         3.073996
# 1072    1.209648         3.025451
# 1073    1.019757         3.025451
# 1190    0.913584         2.707447
# 1191    0.969210         2.707447
# 1324    1.335256         4.478380
# 1325    1.116742         3.697436
# 1328    1.040860         3.697436
# 1329    1.020196         4.478380
# 1342    1.920566        10.915876
# 1343    1.903156         8.696847
# 1344    1.512008         7.890591
# 1345    1.026549         7.890591
# 1346    1.020762         8.696847
# 1347    1.025931        10.915876
# 1348    1.262242         3.018596
# 1349    1.360773         8.398974
# 1352    1.036442         8.398974
# 1353    1.016390         3.018596
# 1366    2.208923         9.141855
# 1367    1.450218         8.284891
# 1368    4.747008        14.346706
# 1369    1.020588        14.346706
# 1370    1.030523         8.284891
# 1371    1.018889         9.141855
# 1420    1.290929         3.328960
# 1421    2.125771         4.937528
# 1424    1.010456         4.937528
# 1425    1.016668         3.328960
# 1444    1.301687         5.173701
# 1445    1.251360         2.819688
# 1446    1.980359         5.975258
# 1447    1.013578         5.975258
# 1448    1.015826         2.819688
# 1449    1.025405         5.173701
# 1456    1.199129         4.607951
# 1458    1.275462         3.303580
# 1459    1.017270         3.303580
# 1461    1.031776         4.607951

# %%
df = rulesTestFold[3]
df.loc[(df['Chi-Square-Test'] >= ChiSquareCriticalValue90)]
# Out:
#                          antecedents                     consequents  \
# 48                           (pasta)                          (beef)
# 49                            (beef)                         (pasta)
# 652                      (margarine)                   (frankfurter)
# 653                    (frankfurter)                     (margarine)
# 992                     (whole milk)              (other vegetables)
# 993               (other vegetables)                    (whole milk)
# 1250          (soda, tropical fruit)                  (citrus fruit)
# 1255                  (citrus fruit)          (soda, tropical fruit)
# 1282            (rolls/buns, yogurt)         (fruit/vegetable juice)
# 1283         (fruit/vegetable juice)            (rolls/buns, yogurt)
# 1304  (whole milk, other vegetables)                       (waffles)
# 1309                       (waffles)  (whole milk, other vegetables)
# 1316              (pork, whole milk)                       (sausage)
# 1321                       (sausage)              (pork, whole milk)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 48              0.007061            0.035035  0.001358    0.192308  5.488968
# 49              0.035035            0.007061  0.001358    0.038760  5.488968
# 652             0.028517            0.037751  0.002988    0.104762  2.775060
# 653             0.037751            0.028517  0.002988    0.079137  2.775060
# 992             0.143400            0.123031  0.010864    0.075758  0.615760
# 993             0.123031            0.143400  0.010864    0.088300  0.615760
# 1250            0.004889            0.048343  0.001086    0.222222  4.596754
# 1255            0.048343            0.004889  0.001086    0.022472  4.596754
# 1282            0.006790            0.035578  0.001086    0.160000  4.497099
# 1283            0.035578            0.006790  0.001086    0.030534  4.497099
# 1304            0.010864            0.022542  0.001358    0.125000  5.545181
# 1309            0.022542            0.010864  0.001358    0.060241  5.545181
# 1316            0.003802            0.060022  0.001086    0.285714  4.760181
# 1321            0.060022            0.003802  0.001086    0.018100  4.760181
#
#       leverage  conviction  Chi-Square-Test
# 48    0.001111    1.194718         4.687913
# 49    0.001111    1.032976         4.687913
# 652   0.001911    1.074852         3.269376
# 653   0.001911    1.054970         3.269376
# 992  -0.006779    0.948852         3.124149
# 993  -0.006779    0.939563         3.124149
# 1250  0.000850    1.223559         2.908836
# 1255  0.000850    1.017987         2.908836
# 1282  0.000845    1.148121         2.778922
# 1283  0.000845    1.024492         2.778922
# 1304  0.001113    1.117095         4.714584
# 1309  0.001113    1.052543         4.714584
# 1316  0.000858    1.315970         3.104786
# 1321  0.000858    1.014561         3.104786

# %%
df= rulesTestFold[3]
df
# Out:
#                antecedents           consequents  antecedent support  \
# 0               (UHT-milk)        (bottled beer)            0.018468
# 1           (bottled beer)            (UHT-milk)            0.043183
# 2               (UHT-milk)       (bottled water)            0.018468
# 3          (bottled water)            (UHT-milk)            0.062194
# 4             (newspapers)            (UHT-milk)            0.041282
# ...                    ...                   ...                 ...
# 1353        (soda, yogurt)          (whole milk)            0.006247
# 1354  (yogurt, whole milk)                (soda)            0.010864
# 1355                (soda)  (yogurt, whole milk)            0.097230
# 1356          (whole milk)        (soda, yogurt)            0.143400
# 1357              (yogurt)    (soda, whole milk)            0.079305
#
#       consequent support   support  confidence      lift  leverage  \
# 0               0.043183  0.001630    0.088235  2.043285  0.000832
# 1               0.018468  0.001630    0.037736  2.043285  0.000832
# 2               0.062194  0.001630    0.088235  1.418700  0.000481
# 3               0.018468  0.001630    0.026201  1.418700  0.000481
# 4               0.018468  0.001086    0.026316  1.424923  0.000324
# ...                  ...       ...         ...       ...       ...
# 1353            0.143400  0.001630    0.260870  1.819170  0.000734
# 1354            0.097230  0.001630    0.150000  1.542737  0.000573
# 1355            0.010864  0.001630    0.016760  1.542737  0.000573
# 1356            0.006247  0.001630    0.011364  1.819170  0.000734
# 1357            0.014123  0.001630    0.020548  1.454953  0.000510
#
#       conviction  Chi-Square-Test
# 0       1.049412         0.832791
# 1       1.020023         0.832791
# 2       1.028561         0.197102
# 3       1.007941         0.197102
# 4       1.008060         0.131806
# ...          ...              ...
# 1353    1.158929         0.636225
# 1354    1.062083         0.313940
# 1355    1.005997         0.313940
# 1356    1.005176         0.636225
# 1357    1.006560         0.230111
#
# [1358 rows x 10 columns]

# %% [markdown]
# ## How to plot our results?

# %%
dfSeason_DiffInMain[2]
# Out:
#                antecedents            consequents
# 0               (UHT-milk)        (bottled water)
# 1          (bottled water)             (UHT-milk)
# 2               (UHT-milk)     (other vegetables)
# 3       (other vegetables)             (UHT-milk)
# 4                 (pastry)             (UHT-milk)
# ..                     ...                    ...
# 289        (soda, sausage)           (whole milk)
# 290  (whole milk, sausage)                 (soda)
# 291                 (soda)  (whole milk, sausage)
# 292           (whole milk)        (soda, sausage)
# 293              (sausage)     (soda, whole milk)
#
# [294 rows x 2 columns]

# %%
dfSeason_DiffInTest[2]
# Out:
#             antecedents           consequents
# 0            (UHT-milk)        (bottled beer)
# 1        (bottled beer)            (UHT-milk)
# 2                (beef)        (bottled beer)
# 3        (bottled beer)                (beef)
# 4         (butter milk)                (beef)
# ..                  ...                   ...
# 589      (soda, yogurt)          (whole milk)
# 590  (soda, whole milk)              (yogurt)
# 591            (yogurt)    (soda, whole milk)
# 592        (whole milk)        (soda, yogurt)
# 593              (soda)  (yogurt, whole milk)
#
# [594 rows x 2 columns]

# %%
dfSeason_overlap[2]
# Out:
#                antecedents            consequents
# 0             (rolls/buns)             (UHT-milk)
# 1               (UHT-milk)           (rolls/buns)
# 2               (UHT-milk)       (tropical fruit)
# 3         (tropical fruit)             (UHT-milk)
# 4               (UHT-milk)           (whole milk)
# ..                     ...                    ...
# 875      (yogurt, sausage)           (whole milk)
# 876  (whole milk, sausage)               (yogurt)
# 877               (yogurt)  (whole milk, sausage)
# 878           (whole milk)      (yogurt, sausage)
# 879              (sausage)   (yogurt, whole milk)
#
# [880 rows x 2 columns]

# %%
statusOnlyInTest = 'Only in Test'
StatisticallySignificantOverperform = 'Relative High confidence'
StatisticallySignificantUnderperform = 'Relative Low confidence'
StatisticallySignificant = 'Statistically Significant'

# %%
dfSeason_DiffInTest[1]
# Out:
#                antecedents            consequents
# 0               (UHT-milk)        (bottled water)
# 1          (bottled water)             (UHT-milk)
# 2          (cream cheese )             (UHT-milk)
# 3               (UHT-milk)        (cream cheese )
# 4                   (curd)             (UHT-milk)
# ..                     ...                    ...
# 683        (soda, sausage)           (whole milk)
# 684  (whole milk, sausage)                 (soda)
# 685                 (soda)  (whole milk, sausage)
# 686           (whole milk)        (soda, sausage)
# 687              (sausage)     (soda, whole milk)
#
# [688 rows x 2 columns]

# %%
AllRules = rulesTestFold[1][['antecedents','consequents']] 

def assemblyClassification(dfSeason_DiffInTest,dfSeason):
    classification = []
    for season in range(seasons):
        DiffInTest = dfSeason_DiffInTest[season]
        DiffInTest['Classification'] = statusOnlyInTest
        df=  dfSeason[season][['antecedents','consequents','Chi-Square-Test','conviction']] 
        df['Classification'] = 'normal'
        # df[((df['Chi-Square'] >= ChiSquareCriticalValue90) & (df['Confidence Ratio'] >= 1.2)), 'Classification']=StatisticallySignificantOverperform
        df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90), StatisticallySignificant, df['Classification'])
        df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] >= 1.5), StatisticallySignificantOverperform, df['Classification'])
        df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] <= 0.75), StatisticallySignificantUnderperform , df['Classification'])
        df = df.drop(columns=['Chi-Square-Test'])
        rulesTest = pd.concat([DiffInTest,df])
        rulesTest.reset_index(drop=True)
        classification.append(rulesTest)
        
    return classification

# %%
classification = assemblyClassification(dfSeason_DiffInTest,rulesTestFold)
# Out:
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = 'normal'
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90), StatisticallySignificant, df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] >= 1.5), StatisticallySignificantOverperform, df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] <= 0.75), StatisticallySignificantUnderperform , df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = 'normal'
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90), StatisticallySignificant, df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] >= 1.5), StatisticallySignificantOverperform, df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] <= 0.75), StatisticallySignificantUnderperform , df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = 'normal'
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90), StatisticallySignificant, df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] >= 1.5), StatisticallySignificantOverperform, df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] <= 0.75), StatisticallySignificantUnderperform , df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = 'normal'
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90), StatisticallySignificant, df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] >= 1.5), StatisticallySignificantOverperform, df['Classification'])
# /var/folders/3y/s1rdyf692tndnh2wdgdpfx0c0000gn/T/ipykernel_10305/2263716792.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classification'] = np.where((df['Chi-Square-Test'] >= ChiSquareCriticalValue90) & (df['conviction'] <= 0.75), StatisticallySignificantUnderperform , df['Classification'])

# %%
dataFinal = []
for season in range(seasons):
    df = classification[season]
    countOnlyInTest = df['Classification'].loc[(df['Classification'] == statusOnlyInTest)].count()
    countNormal = df['Classification'].loc[(df['Classification'] == 'normal')].count()
    countUnder = df['Classification'].loc[(df['Classification'] == StatisticallySignificantUnderperform)].count()
    countSS = df['Classification'].loc[(df['Classification'] == StatisticallySignificant)].count()
    countOver = df['Classification'].loc[(df['Classification'] == StatisticallySignificantOverperform)].count()
    dataFinal.append([countOnlyInTest,countNormal,countUnder,countSS,countOver])
print(dataFinal)
# Out:
# [[720, 1572, 0, 21, 3], [688, 1582, 0, 21, 1], [594, 1428, 0, 39, 7], [454, 1344, 0, 14, 0]]

# %%
dataFinal = np.array(dataFinal)
dataFinal = dataFinal.reshape(4,5)
dataFinal = np.transpose(dataFinal)
dataFinal
# Out:
# array([[ 720,  688,  594,  454],
#        [1572, 1582, 1428, 1344],
#        [   0,    0,    0,    0],
#        [  21,   21,   39,   14],
#        [   3,    1,    7,    0]])

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 4
InTestValues = dataFinal[0]
normalValues = dataFinal[1]
SSUnderValues = dataFinal[2]
SSValues = dataFinal[3]
SSOverValues = dataFinal[4]

ind = np.arange(N) # the x locations for the groups
width = 0.35
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.bar(ind, InTestValues, width, color='r')
ax.bar(ind, normalValues, width,bottom=InTestValues, color='b') # you need to properly stack them ffs
ax.bar(ind, SSUnderValues, width,bottom=normalValues, color='g')
ax.bar(ind, SSValues, width,bottom=SSUnderValues, color='cyan')
ax.bar(ind, SSOverValues, width,bottom=SSValues, color='black')

ax.set_ylabel('Scores')
ax.set_title('Scores by Season')
ax.set_xticks(ind, ('Spring', 'Summer', 'Fall', 'Winter'))
ax.set_yticks(np.arange(0, 100, 100))
ax.legend(labels=[statusOnlyInTest,'normal',StatisticallySignificantUnderperform,StatisticallySignificant,StatisticallySignificantOverperform])
plt.show()

# %%
# for season in range(seasons):
#     classification[season].reset_index(drop=True)
#     classification[season][['Season']] = season
# classification = pd.concat(classification)
# classification

# %%
AllRules = rulesTestFold[3][['antecedents','consequents']] 
AllRules
# Out:
#                antecedents           consequents
# 0               (UHT-milk)        (bottled beer)
# 1           (bottled beer)            (UHT-milk)
# 2               (UHT-milk)       (bottled water)
# 3          (bottled water)            (UHT-milk)
# 4             (newspapers)            (UHT-milk)
# ...                    ...                   ...
# 1353        (soda, yogurt)          (whole milk)
# 1354  (yogurt, whole milk)                (soda)
# 1355                (soda)  (yogurt, whole milk)
# 1356          (whole milk)        (soda, yogurt)
# 1357              (yogurt)    (soda, whole milk)
#
# [1358 rows x 2 columns]

# %% [markdown]
# ## Limitations
#
# In the test fold, because we have less data, weobtain more rules than for a bigger dataset, as a particular rule needs less occurrence of its antecedents and consequents in order for the support to be above the threshold.
